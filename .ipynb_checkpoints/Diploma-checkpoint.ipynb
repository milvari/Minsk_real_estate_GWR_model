# %%
# Импорт библиотек

import os
import osmnx as ox # экспорт данных осм
import numpy as np # работа с массивами
import seaborn as sns
import scipy # статистический
import pandas as pd # серии и фреймы данных
import shapely # работа с геометрией
import geopandas as gpd # геодатафреймы и геосерии
import libpysal as lps # пространсвенная эконометрика
from libpysal.weights import *
import matplotlib.pyplot as plt # визуализация
from matplotlib_scalebar.scalebar import ScaleBar
import mapclassify as mc # методы символизации
# %matplotlib inline

# %% [markdown]
# ## 1) Первичная обработка исходного геодатафрейма

# %% [markdown]
# ### 1.1. Загрузка данных

# %%
# получение текущей рабочей директории
print(os.getcwd())

# изменение директории Minsk_2017
os.chdir('Minsk_2017');
# Out:
# /home/milvari/EnvProj/myenv/scripts/Minsk

# %%
# чтение основного геодатафрейма данных
# вторичная недвижимость, Минск, 2017 год
m17 = gpd.read_file('Minsk_flat_price.shp')
m17.head()
# Out:
#       FID_  Admi_housi  rooms town_name            street_nam  house_numb  \
# 0   5399.0      6029.0    2.0     Минск         Тикоцкого ул.         4.0
# 1  11230.0     11804.0    4.0     Минск             Мавра ул.        25.0
# 2   9305.0      7857.0    2.0     Минск       Шпилевского ул.        52.0
# 3   4084.0      4338.0    2.0     Минск         Васнецова ул.         9.0
# 4   8637.0      9293.0    3.0     Минск  Радиаторный 2-й пер.        20.0
#
#    building_n     price  price_m2  area_total  ...  house_type  date_recep  \
# 0         0.0   37000.0     741.0        49.9  ...           п  2017-12-26
# 1         0.0   77000.0     741.0       103.9  ...           п  2016-11-21
# 2         0.0   55000.0     743.0        74.0  ...           п  2017-06-06
# 3         0.0   33000.0     750.0        44.0  ...           п  2017-05-16
# 4         0.0  125000.0     752.0       166.2  ...          сб  2017-11-03
#
# ...

# %%
# Выявление формы датафрейма --> (строки, столбцы)
m17.shape
# Out:
# (5906, 21)

# %%
# Просмотр структуры датафрейма
m17.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5906 entries, 0 to 5905
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FID_        5906 non-null   float64
#  1   Admi_housi  5906 non-null   float64
#  2   rooms       5906 non-null   float64
#  3   town_name   5906 non-null   object
#  4   street_nam  5906 non-null   object
#  5   house_numb  5906 non-null   float64
#  6   building_n  5906 non-null   float64
#  7   price       5906 non-null   float64
#  8   price_m2    5906 non-null   float64
#  9   area_total  5906 non-null   float64
#  10  building_y  5906 non-null   float64
#  11  house_type  5892 non-null   object
#  12  date_recep  5901 non-null   object
#  13  agency      3252 non-null   object
#  14  code        5906 non-null   float64
#  15  priority    5906 non-null   float64
#  16  counter     5906 non-null   float64
#  17  x           5906 non-null   float64
# ...

# %% [markdown]
# ### 1.2. Работа с СК

# %%
# Работа с системой координат
local_crs = m17.estimate_utm_crs() 
m17.to_crs(local_crs, inplace=True)
m17.crs # - это атрибут геодатафрейма
# Out:
# <Derived Projected CRS: EPSG:32635>
# Name: WGS 84 / UTM zone 35N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 24°E and 30°E, northern hemisphere between equator and 84°N, onshore and offshore. Belarus. Bulgaria. Central African Republic. Democratic Republic of the Congo (Zaire). Egypt. Estonia. Finland. Greece. Latvia. Lesotho. Libya. Lithuania. Moldova. Norway. Poland. Romania. Russian Federation. Sudan. Svalbard. Turkey. Uganda. Ukraine.
# - bounds: (24.0, 0.0, 30.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 35N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ### 1.3. Проверка уникальности первичного ключа

# %%
# Проверка уникальности первичного ключа FID_
len(m17) == len(m17['FID_'].unique())
# Out:
# True

# %%
# Индекс - это реализация первичного ключа для датафрейма в Pandas
m17.set_index('FID_',inplace=True)

# %% [markdown]
# ### 1.4. Удаление избыточных атрибутов

# %%
# Удаление избыточных атрибутов, переименование
m17.drop(['Admi_housi','town_name','price',
         'date_recep','agency','code','priority','counter', 'Id_me'],
         axis=1,
         inplace = True
        );
m17.rename(columns = {'building_y':'year'}, inplace=True);

# %% [markdown]
# Тип дома - качественный атрибут массива (тип строчный),
# для дальнейшей обработки каждое уникальное значение
# станет бинарным атрибутом
# просмотр уникальных значений
# vc = m17['house_type'].value_counts() # --> 9
# vc

# %%
# Выберем те значения года постройки, которые отсутствуют, а также текущего года постройки
# и удалим
m17 = m17[m17['year'] != 0]
m17 = m17[m17['year'] != 2017]
m17 = m17[m17['year'] != 2018]
m17 = m17[m17['year'] != 2019]
m17 = m17[m17['year'] != 2020]

# Просмотрим значения типа дома вновь
m17['year'].value_counts()
# Out:
# 2014.0    176
# 2015.0    172
# 2016.0    151
# 2013.0    145
# 2010.0    133
#          ...
# 1937.0      2
# 1918.0      2
# 1927.0      1
# 1935.0      1
# 1911.0      1
# Name: year, Length: 80, dtype: int64

# %%
# Выберем те значения материала стен, которые встречаются менее 100 раз
vc = m17['house_type'].value_counts()
to_remove = vc[vc <= 100].index

# И удалим
m17 = m17[~m17.house_type.isin(to_remove)]

# Просмотрим значения типа дома вновь
m17['house_type'].value_counts()
# Out:
# п     2631
# к     1515
# кб     537
# б      184
# м      155
# Name: house_type, dtype: int64

# %% [markdown]
# преобразуем категориальную переменные в индикаторные
#
# m17 = m17.join(pd.get_dummies(m17.house_type));

# %% [markdown]
# m17.rename(columns = {'п':'p',
#                       'кб':'kb',
#                       'м':'m',
#                       'б':'b',
#                       'сб':'sb',
#                       'к':'k'}, inplace=True);

# %%
# Изменение буквенных значений стен на цифровые
m17.replace(regex={'п': 1.0, 'к':2.0,'кб': 3.0,
                   'м': 4.0,'б': 5.0,'сб':6.0},
           inplace = True)

# %%
m17.shape
# Out:
# (5034, 11)

# %% [markdown]
# ### 1.5. Выявление и чистка необпределенных значений

# %%
# Выявление пустых значений (Null)
m17.isnull().sum()
# Удаление Null-значений, повторная проверка
m17.dropna(axis=0, inplace=True)

# %% [markdown]
# ### 1.6. Удаление дубликатов точек по местоположению

# %%
m17 = m17.drop_duplicates('geometry')

# %%
m17.shape
# Out:
# (3875, 11)

# %% [markdown]
# ## 2) Добавим структурные факторы при помощи Spatial Join

# %% [markdown]
# ### 2.1. Источники водоснабжения

# %%
v = gpd.read_file('Источники_водоснабжения.shp')
voda = [1,3,2]
v['foundat'] = voda

# %% [markdown]
# undergr = m17[m17.within(v.geometry.values[0])]
# undergr['found'] = 3.0
# surf = m17[m17.within(v.geometry.values[1])]
# surf['found'] = 1.0
# mix = m17[m17.within(v.geometry.values[2])]
# mix['found'] = 2.0
#
# m17 = pd.concat([undergr, surf, mix])

# %%
a = gpd.sjoin(m17,v, how='inner',predicate ='within')

# %%
a.drop(['index_right','SHAPE_Leng',
         'SHAPE_Area'], axis=1, inplace = True
       );
a.rename(columns = {'foundat_right':'foundat',
                     'Источ':'Istoch'}, inplace=True); 
m17 = a

# %%
m17['foundat'] = m17['foundat'].astype(float)

# %%
m17['foundat'].value_counts()
# Out:
# 1.0    2665
# 3.0    1074
# 2.0     136
# Name: foundat, dtype: int64

# %% [markdown]
# преобразуем категориальную переменные в индикаторные
#
# m17 = m17.join(pd.get_dummies(m17.Istoch));

# %%
f1 = m17[m17['foundat'] == 1.0]
f1['foundat']= np.random.uniform(0.8, 1.0, size=(len(f1),1))

f2 = m17[m17['foundat'] == 2.0]
f2['foundat']= np.random.uniform(1.8, 2.0, size=(len(f2),1))

f3 = m17[m17['foundat'] == 3.0]
f3['foundat']= np.random.uniform(2.8, 3.0, size=(len(f3),1))
# Out:
# /home/milvari/EnvProj/myenv/lib/python3.10/site-packages/geopandas/geodataframe.py:1472: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /home/milvari/EnvProj/myenv/lib/python3.10/site-packages/geopandas/geodataframe.py:1472: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /home/milvari/EnvProj/myenv/lib/python3.10/site-packages/geopandas/geodataframe.py:1472: SettingWithCopyWarning:
# ...

# %%
founds = [f1,f2,f3]
m17 = pd.concat(founds)

# %% [markdown]
# ### 2.2. Этажность

# %%
# загружаем шейп полигонов зданий, оставляем только два атрибута - геометрию и этажность
res = gpd.read_file('Minsk_building_residential.shp')
res = res[['B_LEVELS', 'geometry']]

# %%
m17 = gpd.sjoin_nearest(m17,res, how='inner',max_distance = 10)

# %%
m17.drop(['index_right'],
         axis = 1,        
          inplace=True)
m17.rename(columns = {'B_LEVELS' : 'floors'}, inplace=True)
m17['floors'] = m17['floors'].astype(int)

# %% [markdown]
# ### 2.3. Просмотр промежуточного датафрейма, который содержит все структурные факторы

# %%
m17.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Float64Index: 3506 entries, 5399.0 to 5819.0
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rooms       3506 non-null   float64
#  1   street_nam  3506 non-null   object
#  2   house_numb  3506 non-null   float64
#  3   building_n  3506 non-null   float64
#  4   price_m2    3506 non-null   float64
#  5   area_total  3506 non-null   float64
#  6   year        3506 non-null   float64
#  7   house_type  3506 non-null   float64
#  8   x           3506 non-null   float64
#  9   y           3506 non-null   float64
#  10  geometry    3506 non-null   geometry
#  11  Istoch      3506 non-null   object
#  12  foundat     3506 non-null   float64
#  13  floors      3506 non-null   int64
# dtypes: float64(10), geometry(1), int64(1), object(2)
# memory usage: 410.9+ KB

# %%
## Далее неудачная попытка сделать факторный анализ

# %% [markdown]
# from pandas.plotting import scatter_matrix
# scatter_matrix(m17)

# %% [markdown]
# Стандартизация!!!
#
# m17w = m17.copy()
# m17w.drop(['house_numb','building_n','street_nam',
#            'price_m2','geometry','x','y','Istoch'],
#          axis=1,
#          inplace = True
#         );

# %% [markdown]
# import math
# from sklearn import preprocessing
#
# considered_features = ['rooms',
#                        'area_total',
#                        'year',
#                        'house_type',
#                        'foundat',
#                        'floors']
#
# def scale_features(df,considered_features):
#     scaled = preprocessing.StandardScaler().fit_transform(df)
#     scaled = pd.DataFrame(scaled, columns=considered_features)
#     return scaled

# %% [markdown]
# m17s = scale_features(m17w,considered_features)

# %% [markdown]
# from sklearn.decomposition import FactorAnalysis
#
# m17_scaled = preprocessing.scale(m17w)
# fa = FactorAnalysis(n_components = 2)
# fa.fit(m17_scaled)

# %% [markdown]
# pd.DataFrame(fa.components_, columns = m17w.columns)

# %% [markdown]
# fa.noise_variance_

# %% [markdown]
# m17s

# %% [markdown]
# ## 3) Получение данных OSM для анализа и визуализации (osmnx)

# %% [markdown]
# ### 3.1. Атрибуты близости

# %%
# Определяем место (Минск, Беларусь) и повторно - проекционную систему координат
place = 'Minsk, Belarus'
local_crs = m17.estimate_utm_crs() # WGS 84 / UTM zone 35N

# %%
# Интерактивная проверка инструментом геокодирования
gpd.tools.geocode(place).explore(                              
         tiles="Stamen Watercolor" # use "CartoDB positron" tiles
                                )
# Out:
# <frozen importlib._bootstrap>:914: ImportWarning: _SixMetaPathImporter.find_spec() not found; falling back to find_module()
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# m = ox.graph_from_place(place)

# %% [markdown]
# fix, ax = ox.plot_graph(m,
#                        figsize=(10,10),
#                        bgcolor = 'white',
#                        node_color = 'black',
#                        node_size = 3,
#                        node_alpha = 0.3,
#                        edge_color = 'black',
#                        edge_linewidth = 0.1,
#                        edge_alpha = 0.3,
#                        show=False,
#                        close=False)
# m17.plot(column = 'price_m2', ax=ax,
#          scheme = 'StdMean',cmap = 'spring',
#          markersize=5, edgecolor = 'k',legend = True)
#
# set title, legend_name, scale..........

# %% [markdown]
# mw = ox.graph_from_place(place,network_type='walk')

# %% [markdown]
# fix, ax = ox.plot_graph(mw,
#                      figsize=(10,10),
#                       bgcolor = 'white',
#                        node_color = 'black',
#                        node_size = 3,
#                        node_alpha = 0.3,
#                        edge_color = 'black',
#                        edge_linewidth = 0.1,
#                        edge_alpha = 0.3,
#                        show=False,
#                        close=False)

# %%
# Получение данных ОСМ по обозначаемым тегам и чистка по типу геометрии
# %time

centre = ox.geometries.geometries_from_place(place,
                                           tags = { 'name:be':'Кастрычніцкая'
                                                   #'railway':'station'
                                                   #'addr:street':'Кастрычніцкая плошча'
                                                  });

centre  = centre[centre.geom_type=='Point'].reset_index(drop = True)
m = centre['railway']=='station'
centre = centre[m]

parks = ox.geometries.geometries_from_place(place,
                                           tags = {'leisure':'park',
                                                   'natural':'wood'});
parks = parks[parks.geom_type=='Polygon'].reset_index(drop = True)


metro = ox.geometries.geometries_from_place(place,
                                           tags = {'railway':'station',
                                                  'railway':'subway_entrance'}
                                           );
metro = metro[metro.geom_type=='Point'].reset_index(drop = True)


hospitals = ox.geometries.geometries_from_place(place,
                                           tags = {'amenity':'hospital',
                                                  'amenity':'doctors',
                                                  'amenity':'clinic'
                                                  }
                                           );
hospitals = hospitals[hospitals.geom_type=='Point'].reset_index(drop = True)


schools = ox.geometries.geometries_from_place(place,
                                           tags = {'amenity':'school'}
                                           );
schools = schools[schools.geom_type=='Polygon'].reset_index(drop = True)

transport = ox.geometries.geometries_from_place(place,
                                           tags = {'public_transport':'stop_position'}
                                           ); 
transport = transport[transport.geom_type=='Point'].reset_index(drop = True)

highways = ox.geometries.geometries_from_place(place,
                                           tags = {'highway':['primary', 'trunk']}
                                           );
highways = highways[highways.geom_type=='LineString'].reset_index(drop = True)

industrial = ox.geometries.geometries_from_place(place,
                                           tags = {'landuse':'industrial'}
                                           );
industrial = industrial[industrial.geom_type=='Polygon'].reset_index(drop = True)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.72 µs

# %% [markdown]
# Удаляем избыточные атрибуты - все, кроме столбца геометрии
# (через цикл не идет :-( )
# centre = centre[['geometry']]
# parks=parks[['geometry']]
# metro = metro[['geometry']]
# hospitals = hospitals[['geometry']]
# schools = schools[['geometry']]
# transport = transport[['geometry']]
# highways = highways[['geometry']]
# industrial = industrial[['geometry']]

# %%
# Работа с проекцией (к N35)

centre.to_crs(local_crs, inplace=True)
parks.to_crs(local_crs, inplace=True)
metro.to_crs(local_crs, inplace=True)
hospitals.to_crs(local_crs, inplace=True)
schools.to_crs(local_crs, inplace=True)
transport.to_crs(local_crs, inplace=True)
highways.to_crs(local_crs, inplace=True)
industrial.to_crs(local_crs, inplace=True)

# %% [markdown]
# ### 3.2 Получение зданий и границы города для визуализации

# %%
minsk = ox.geometries.geometries_from_place(query = {'city':'Minsk'},
                                            tags  = {
                                                    'admin_level': '4',
                                                    'name':'Минск'
                                                    });

# %%
# фильтрация по тэгу-тип и присвоение первичного ключа

minsk = minsk[minsk['type']=='boundary'].reset_index(drop=True)
minsk = minsk[['geometry']].to_crs(local_crs)
minsk['uID'] = range(len(minsk))
minsk = minsk.loc[minsk['uID']==0]

# %%
# в результате --> один объект - мультиполигон
minsk
# Out:
#                                             geometry  uID
# 0  MULTIPOLYGON (((558532.867 5970840.893, 558517...    0

# %%
# Разобъем его (взорвем) на полигоны
minsk = minsk.explode(index_parts=True)
minsk
# Out:
#      uID                                           geometry
# 0 0    0  POLYGON ((558532.867 5970840.893, 558517.699 5...
#   1    0  POLYGON ((524818.174 5969095.911, 524755.121 5...
#   2    0  POLYGON ((566076.512 5975311.058, 566344.933 5...

# %%
# Получим наибольший из полигонов - он и будет границей Минска в пределах кольца 
minsk = max(minsk['geometry'], key=lambda a: a.area)

# %%
# Обернем геометрию границы в геодатафрейм
minsk = gpd.GeoDataFrame(index=[0],
                        crs = 'EPSG:32635',
                        geometry = [minsk])
minsk
# Out:
#                                             geometry
# 0  POLYGON ((524818.174 5969095.911, 524755.121 5...

# %%
buildings = ox.geometries.geometries_from_place(place,
                                           tags = {
                                                   'building':'residential'
                                                  });

# %%
# фильтрация по geom.type=='Polygon'

buildings = buildings[buildings.geom_type=='Polygon'].reset_index(drop = True)

# определение проекционной системы
buildings = buildings[['geometry']].to_crs(local_crs)

# обрезание зданий по границе
buildings = gpd.clip(buildings, minsk)

# %% [markdown]
# ## 4) Связь с БД для быстрого получения расстояния до PoI
#
# ### SQLAlchemy - для работы с SQLite, необходимо установить движок DBAPI (для postgres - это psycopg2)

# %% [markdown]
# ### Для этого изначально была создана БД с расширением PostGIS, которое позволяет работать с пространсвенными данными. При установлении расширения в БД автоматически подтягивается таблица spatial_ref_sys, имплементирующая проекции, она подразумевает под собой специальные типы данных (geometry, geography и другие), более 700 функций для работы с геотипами данных.

# %%
from sqlalchemy import create_engine

# %%
# создание движка для подключения к базе данных
engine = create_engine("postgresql+psycopg2://postgres:malica@localhost:5432/geo")

# %%
# подключение к базе данных
engine.connect()

# %%
# DROP TABLE centre, highways, hospitals, industrial, metro, parks, property, schools, transport, distances, heavy_ind

# экспорт необходимых данных в БД - gpf.to_postgis

# %% [markdown]
# centre.to_postgis('centre',con=engine)
# parks.to_postgis('parks',con=engine)
# metro.to_postgis('metro',con=engine)
# hospitals.to_postgis('hospitals',con=engine)
# schools.to_postgis('schools',con=engine)
# transport.to_postgis('transport',con=engine)
# highways.to_postgis('highways',con=engine)
# industrial.to_postgis('industrial',con=engine)
# m17.to_postgis('property',con=engine, index= 'FID_')

# %% [markdown]
# ### В самой БД я почистила индустриальные зоны, выделила пару предприятий тяжелой промышленности в отдельную таблицу,выполнила запрос, возвращающий таблицу с минимальным расстояниями до пунктов интересов от объектов недвижимости

# %%
# DROP TABLE centre, highways, hospitals, industrial, metro, parks, property, schools, transport, distances, heavy_ind

#------- чистка индустриальных зон-----
# DELETE FROM industrial i
# WHERE 'name:ru' IS NULL
# OR ST_AREA(geometry)/10000 < 3
# OR name LIKE '% парк %';

#--------выделение пары предприятий тяжелой промышленности------------
# CREATE TABLE heavy_ind
# AS (
# SELECT *
# FROM industrial i
# WHERE i.name = 'Минский автомабильный завод'
# or i.name = 'Минский тракторный завод'
# or i.name = 'ТЭЦ-4'
# or i.name = 'Промузел Шабаны'
# or i.name like 'Минские тепловые сети ТЭЦ-%'
# or i.name = 'Минский моторный завод'
# or i.name = 'Минский завод строительных материалов'
# or i.name = 'МЗХ "Атлант"'
# or i.name = '%Керамин%'
#)

# --------- SQL-запрос (minimal_distances.sql)--------------------------

# %% [markdown]
# импорт таблицы из БД - gpd.from_postgis
# distances = gpd.GeoDataFrame.from_postgis('distances',
#                                           con=engine,
#                                           geom_col='geometry')

# %%
distances = pd.read_sql_query('select * from distances',con=engine,
                              index_col='FID_')

# %%
# соединение таблицы с датафреймом (слияние с бесконечно вечным)
m17 = m17.join(distances, on='FID_',how='left', sort='FID_')

# %% [markdown]
# ### Просмотр конечного датафрейма, который содержит и структурные и факторы расстояния до PoI

# %%
m17
# Out:
#          rooms              street_nam  house_numb  building_n  price_m2  \
# FID_
# 0.0        1.0  Героев 120 Дивизии ул.        27.0         0.0    1284.0
# 1.0        1.0  Героев 120 Дивизии ул.        29.0         0.0    1327.0
# 4.0        1.0  Героев 120 Дивизии ул.        33.0         0.0    1190.0
# 23.0       1.0  Героев 120 Дивизии ул.        23.0         0.0    1119.0
# 25.0       1.0          Мстиславца ул.         1.0         0.0    1735.0
# ...        ...                     ...         ...         ...       ...
# 11802.0    4.0                     1.0        35.0         0.0    1023.0
# 11823.0    1.0              Фогеля ул.         1.0         0.0    1089.0
# 11843.0    2.0            Маневича ул.        17.0         0.0     904.0
# 11862.0    3.0         Основателей ул.         7.0         0.0    1065.0
# 11873.0    3.0           Подгорная ул.        19.0         3.0    1693.0
#
#          area_total    year  house_type          x          y  ... floors  \
# ...

# %% [markdown]
# Работа с столбцом геометрии
# m17.drop(['geometry_left'],
#          axis=1,
#          inplace = True
#         )
# m17.rename(columns = {'geometry_right':'geometry'}, inplace=True)
# m17.set_geometry('geometry');

# %% [markdown]
# ### 2.3. Датафрейма можно выгрузить в любой формат данных ГИС, реализуемый библиотекой fiona

# %% [markdown]
# m17.to_file('m17.shp')

# %% [markdown]
# ### 2.4. Разобьем выборку по типологическому признаку - количество комнат

# %%
room1 = m17[m17['rooms'] == 1.0]
room1.to_file('room1.shp')

room2 = m17[m17['rooms'] == 2.0]
room2.to_file('room2.shp')

room3 = m17[m17['rooms'] ==3.0]
room3.to_file('room3.shp')
# Out:
# /tmp/ipykernel_49620/4191031331.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   room1.to_file('room1.shp')
# /tmp/ipykernel_49620/4191031331.py:5: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   room2.to_file('room2.shp')
# /tmp/ipykernel_49620/4191031331.py:8: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   room3.to_file('room3.shp')

# %% [markdown]
# ## 5) Описательная статистика:
# ### число объектов, среднее значение, стандартное отклонение, минимум, максимум,квантили

# %%
# Проверка данных на нормальность распределения

for col in m17.select_dtypes(include=np.number):
    stat,p = scipy.stats.normaltest(m17[col])
    alpha = 0.05
    print("p = {:g}".format(p))

    if p < alpha:  # null hypothesis: x comes from a normal distribution
        print("The % has a non-normal distribution."%col)
    else:
        print("The % has a normal distribution."%col)
        
# ИТОГ имеют нормальное распределение: все факторы близости и местоположения
#       не-нормальное: комнатность (категориальный!), цена за м2, общая площадь,
#                      год постройки, материал стен (категориальный!), источники водоснабжения (категориальный!),
#                      этажность дома
# Out:
# p = 4.12232e-106
# The 'rooms's a non-normal distribution.
# p = 7.28932e-206
# The 'house_numb's a non-normal distribution.
# p = 0
# The 'building_n's a non-normal distribution.
# p = 1.7446e-192
# The 'price_m2's a non-normal distribution.
# p = 0
# The 'area_total's a non-normal distribution.
# p = 9.0078e-242
# The 'year's a non-normal distribution.
# p = 0
# The 'house_type's a non-normal distribution.
# p = 1.50124e-205
# The 'x's a non-normal distribution.
# p = 2.59707e-172
# The 'y's a non-normal distribution.
# p = 0
# The 'foundat's a non-normal distribution.
# p = 9.82895e-172
# The 'floors's a non-normal distribution.
# p = 2.21463e-119
# The 'centre_dist's a non-normal distribution.
# p = 3.16392e-85
# The 'parks_dist's a non-normal distribution.
# p = 4.96792e-68
# The 'metro_dist's a non-normal distribution.
# p = 9.85495e-148
# The 'hospitals_dist's a non-normal distribution.
# p = 0
# The 'schools_dist's a non-normal distribution.
# p = 1.61967e-107
# ...

# %% [markdown]
# m17['price_m2'].mode()
# m17['price_m2'].median()
# m17['price_m2'].describe()

# %% [markdown]
# #m17['price_m2'].mode()
# from scipy.stats import skew
# skew(m17['price_m2'],bias= False)

# %% [markdown]
# from scipy.stats import kurtosis
# kurtosis(m17['price_m2'],bias= False)

# %%
# Гистограмма распределения зависимой переменной - цены за м2
# Асимметрична, унимодальна

prices = m17['price_m2'].values
plt.hist(prices, bins=40, color='m')
plt.ylabel('Статистика')
plt.xlabel('Данные')
plt.savefig('Hist0.png', dpi=300)

# %%
# Работа с выбросами - просмотрим квантили от 0,95 до 0,99
qua = []
for i in np.arange(0.94,1.0, 0.01):
    q = m17['price_m2'].quantile(i)
    qua.append(q)
plt.plot(np.arange(0.94,1.0, 0.01),qua) # --> выбираем квантиль 0.99

# %%
# Отчистим массив, ограничевшись кватилем 99%

m17 = m17[m17['price_m2']<m17['price_m2'].quantile(0.99)]

# %%
# Гистограмма распределения 

prices = m17['price_m2'].values
plt.hist(prices, bins=40)
plt.ylabel('Статистика')
plt.xlabel('Данные')
#plt.savefig('Hist1.png', dpi=300)
# Out:
# Text(0.5, 0, 'Данные')

# %%
# прологарифмирую зависимую переменную
m17['price_m2_log'] = np.log(m17['price_m2'])
# Out:
# /home/milvari/EnvProj/myenv/lib/python3.10/site-packages/geopandas/geodataframe.py:1472: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %% [markdown]
# Проверка на нормальность
#
# stat,p = scipy.stats.normaltest(m17['price_m2'])
# alpha = 0.05
# print("p = {:g}".format(p)) # --> отклоняем нулевую гипотезу о нормальности

# %%
prices = m17['price_m2_log'].values
plt.hist(prices, bins=40, color='c', rwidth=0.9)
plt.ylabel('Статистика')
plt.xlabel('Данные')
plt.savefig('Histlog.png', dpi=300)

# %% [markdown]
# ## 6) Выявление статистических связей

# %% [markdown]
# ### 6.1. Ранговый коэффициент корреляции Спирмена

# %%
## Проверка корреляции между факторами - через матрицу ковариации
considered_features = ['rooms',
                       'area_total',
                       'year',
                       'house_type',
                       'foundat',
                       'floors',
                       'centre_dist',
                       'parks_dist',
                       'metro_dist',
                      'hospitals_dist',
                      'schools_dist',
                      'transport_dist',
                      'highways_dist',
                      'industrial_dist',
                      'heavy_dist']
X = m17[considered_features]

# получение матрицы корреляций значений - видна корреляция только комнатности и общей площади
plt.figure(figsize=(10,10))
mask = np.triu(np.ones_like(X.corr(method = 'spearman'), dtype=bool))


sns.heatmap(X.corr(method = 'spearman'),
            annot=True, mask=mask, fmt='.1g', 
            cmap='spring', vmin=-1, vmax=1)

plt.savefig('corr0.png', dpi=300)

# %% [markdown]
# ### 6.2. Проверка мультиколлинеарности

# %%
# load statmodels functions
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# compute the vif for all given features
def compute_vif(considered_features):
    
    X = m17[considered_features]
    # the calculation of variance inflation requires a constant
    X['intercept'] = 1
    
    # create dataframe to store vif values
    vif = pd.DataFrame()
    vif["Variable"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif = vif[vif['Variable']!='intercept']
    return vif

# %%
# compute vif 
compute_vif(considered_features).sort_values('VIF', ascending=False)
# Out:
# /tmp/ipykernel_49620/1487313439.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['intercept'] = 1
#            Variable       VIF
# 1        area_total  3.432549
# 2              year  3.287207
# 0             rooms  2.838616
# 6       centre_dist  2.350788
# 5            floors  1.896590
# 4           foundat  1.832606
# 14       heavy_dist  1.470591
# 8        metro_dist  1.460995
# 12    highways_dist  1.453316
# 9    hospitals_dist  1.429693
# 13  industrial_dist  1.374215
# 10     schools_dist  1.162255
# 3        house_type  1.095453
# 7        parks_dist  1.074457
# 11   transport_dist  1.033453

# %% [markdown]
# ## 7) Пространсвенная эконометрика

# %% [markdown]
# ### 7.1. Просмотрим распределение цен по Минску, при помощи простой визуализации

# %%
from mpl_toolkits.axes_grid1.anchored_artists import AnchoredSizeBar

# %%
f,ax = plt.subplots (1, figsize = (8.26,5.826)) # 2551x1795 - A5 (dpi-300)

minsk.plot(ax=ax, color = 'c',alpha = .1, edgecolor = 'red')
highways.plot(ax=ax, color = 'grey', alpha = 0.2)
buildings.plot(ax=ax, color='grey', alpha = 0.5)


m17.plot(column = 'price_m2',
         ax=ax,
         scheme = 'StdMean',
         cmap = 'plasma',
         markersize= 8,
         edgecolor = 'none'
         ,legend= True,
         legend_kwds = {'frameon':False,
                       'loc':3,
                        'ncol':1,
                       'fontsize':9}
        )
#ax.set_title('Цена за кв.м, г.Минск,2017 (Std.Mean)',fontsize = 14)
#ax.legend(loc='lower left')
# scalebar = AnchoredSizeBar(ax.transData, 1, "1 Meter", 9)
#ax.legend(frameon=False, loc=0, ncol=2)
ax.add_artist(ScaleBar(dx = 1, location = 'lower right')) # 1 pixel = 1 м

ax.set_axis_off()
plt.savefig('StdMean.png', format='png', dpi=300)

# %%
# Посмотрели на медиану зависимой переменной
y = m17.price_m2
y.median()
# Out:
# 1161.0

# %%
# Выбрали значения выше медианы
yb = y > y.median()
sum(yb)
# Out:
# 1732

# %%
labels = ["0 Ниже", "1 Выше"]
yb = [labels[i] for i in 1*yb]

# %%
m17['yb'] = yb
m17.head()
# Out:
# /home/milvari/EnvProj/myenv/lib/python3.10/site-packages/geopandas/geodataframe.py:1472: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#       rooms              street_nam  house_numb  building_n  price_m2  \
# FID_
# 0.0     1.0  Героев 120 Дивизии ул.        27.0         0.0    1284.0
# 1.0     1.0  Героев 120 Дивизии ул.        29.0         0.0    1327.0
# 4.0     1.0  Героев 120 Дивизии ул.        33.0         0.0    1190.0
# 23.0    1.0  Героев 120 Дивизии ул.        23.0         0.0    1119.0
# 25.0    1.0          Мстиславца ул.         1.0         0.0    1735.0
#
#       area_total    year  house_type          x          y  ...  parks_dist  \
# ...

# %%
f,ax = plt.subplots (1, figsize = (8.26,5.826)) 

minsk.plot(ax=ax, color = 'lightcoral',alpha = .2, edgecolor = 'red')
highways.plot(ax=ax, color = 'grey', alpha = 0.2)
buildings.plot(ax=ax, color='grey', alpha = 0.5)

m17.plot(column='yb', cmap='binary',
         ax=ax,
         edgecolor='grey',
         linewidth = 0.2,
         legend=True,
         legend_kwds = {'frameon':False,
                       'loc':3,
                        'ncol':1,
                        'edgecolor':'k',
                        'fontsize':9},
         markersize = 10)
#ax.legend()
ax.add_artist(ScaleBar(dx = 1,
                       location = 'lower right'
                      )) # 1 pixel = 1 м
#plt.title("Цены за м2 выше/ниже медианы")
ax.set_axis_off()
plt.savefig('Binary.png', format='png', dpi=200)

# %% [markdown]
# ### 7.2. Пространственные весы (выбран Kernel weights - весы расстояния, отражающие первый закон Тоблера) - выражают феномен соседства (spatial similarity)

# %%
# Сontinuously valued weights
# to reflect Tobler’s first law [Tob70] in a more direct way:
# observations that are close to a unit have larger weights
# than more distant observations.

# reflect the case where similarity/spatial proximity
# is assumed or expected to decay with distance

# The essence of kernel weights is
# that the weight between observations i and j is based on
# their distance,
# but it is further modulated by a kernel function
#with certain properties

# %%
#from scipy.spatial import Voronoi,voronoi_plot_2d
#from shapely.geometry import Point, MultiPolygon, Polygon

points = (list(zip(m17['x'], m17['y'])))
points = np.array(points)

# %%
kw = Kernel(points,fixed = False,
            k = 30) # адаптивные - 20 соседей
# Out:
# /home/milvari/EnvProj/myenv/lib/python3.10/site-packages/libpysal/weights/weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#   warnings.warn(message)

# %%
kw.neighbors [0]; # expressing neighboor relationships
             # by expressing the focal observation on the left and right

# %%
c = kw.cardinalities;
pd.Series(c).plot.hist(color="k");

# %%
kw.weights[0];

# %%
print(kw.nonzero)
print(kw.pct_nonzero) # equal to 100*(w.s0/w.n^2)
# Out:
# 107570
# 0.8933717579250721

# %%
kw.s0 # number of joins
# Out:
# 41193.13226429516

# %% [markdown]
# ### 7.2. Атрибутивное сходство (Atribute similarity) - сглаживаем пространсвенным лагом

# %%
kw.transform = 'r'# весовая трансформация,'r' - построчная,
                  # 'B' - бинарная, 'D' - дважды-стандартизированная,
                  # 'U' - без, 'V'-стабилизирующий дисперсию

# %%
# определяем зависимую переменную
y = m17['price_m2']

# %%
# Модель пространсвенного лага - это модель, описывающая эффект
# ПРОСТРАНСТВЕННОЙ ЗАВИСИМОСТИ
# Пространсвенный лаг - это взвешенное среднее соседствующих значений
# зависимой переменной, сумма произведений матрицы весов на вектор наблюдений

# Более гладкая в сравнении с скользящим средним
ylag = lps.weights.lag_spatial(kw,y)

# %%
plt.plot(ylag, linewidth =0.5) # --> видим 5 частей

# %%
# классифицируем на пять квантилей

ylagq5 = mc.Quantiles(ylag, k=5)
ylagq5
# Out:
# Quantiles
#
#      Interval        Count
# --------------------------
# [ 958.52, 1099.73] |   694
# (1099.73, 1143.45] |   694
# (1143.45, 1195.21] |   694
# (1195.21, 1306.18] |   694
# (1306.18, 1782.65] |   694

# %%
f,ax = plt.subplots (1, figsize = (8.26,5.826)) # 2551x1795 - A5 (dpi-300)

minsk.plot(ax=ax, color = 'c',alpha = .1, edgecolor = 'red')
highways.plot(ax=ax, color = 'grey', alpha = 0.2)
buildings.plot(ax=ax, color='grey', alpha = 0.5)


m17.plot(ylag, scheme="Quantiles",
         k=5, cmap='GnBu', linewidth=0.1, ax=ax, 
         edgecolor= 'k', legend=True,
         legend_kwds ={'frameon':False,
                        'loc':3,
                        'ncol':2,
                        'fontsize':9},
         markersize = 10)
                
ax.set_axis_off()
ax.add_artist(ScaleBar(dx = 1,
                       location = 'lower right'
                      ),) # 1 pixel = 1 м
#plt.title("Пространсвенный лаг цена за м2 (Квантили)")
#plt.show()
plt.savefig('SpLag.png', dpi=300)

# %% [markdown]
# ### 7.3. Пространсвенная автокорреляция (глобальная) - про взаимодействие (отражает общую схожесть)

# %% [markdown]
# ### H0: пространсвенная случайность - отсутсвие любого паттерна

# %%
### Непрерывный случай

# %%
# Moran I Test
import esda # работа с автокорреляцией

np.random.seed(12345)

mi = esda.moran.Moran(y, kw)
mi.I # значение коэффициента автокорреляции
# Out:
# 0.4037295465279632

# %%
mi.EI # ожидаемое значение при допущении нормальности
# Out:
# -0.0002882675122513693

# %%
max(mi.sim) # моделируем нулевую гипотезу (случайные пространсвенные перестановки)
# Out:
# 0.10226366952985119

# %%
sns.kdeplot(mi.sim, #(если n(перестановок)>0) вектор значений I для переставленных выборок
            shade=True)
plt.vlines(mi.I, 0, 20, color = 'r')
plt.vlines(mi.EI, 0,20)
plt.xlabel("Моран I")
plt.ylabel("Плотность")
plt.savefig('moran-p.png', dpi=300)
# Out:
# /tmp/ipykernel_49620/2451452076.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(mi.sim, #(если n(перестановок)>0) вектор значений I для переставленных выборок

# %%
mi.p_sim # --> отклоняем пространсвенную случайность

# (если перестановки>0)
# p-значение, основанное на перестановках
# H0: альтернатива пространственной случайности
# наблюдаемое I является экстремальным (высоким или низким)
# полученных на основе перестановок.
# Out:
# 0.001

# %% [markdown]
# ### 7.4. Локальная автокорреляция (ЛИЗА)

# %%
# Отобразим диаграмму рассеяния Морана - отражающую зависимость
# зависимой переменной от ее пространсвенного лага, в нашем случае
# это линейная положительная зависимость, визуализирующая взаимодействие. 

y = m17['price_m2']
b, a = np.polyfit(y, ylag, 1)
f, ax = plt.subplots(1, figsize=(9, 9))

plt.plot(y, ylag, '.', color = 'firebrick')

# dashed vert at mean of the price
plt.vlines(y.mean(), ylag.min(), ylag.max(), linestyle='--')

# dashed horizontal at mean of lagged price

plt.hlines (ylag.mean(), y.min(), y.max(), linestyle = '--')

# red line of best fit using global moran
plt.plot(y, a + b*y, 'r')
#plt.title('Диаграмма рассеяния Морана')
plt.ylabel('Пространсвенный лаг цены')
plt.xlabel('Цена')
plt.savefig('moran_scatter.png', dpi=300)

# %%
# Расчитываем Локальный Индекс Морана

li = esda.moran.Moran_Local(y, kw)
# Out:
# <frozen importlib._bootstrap>:914: ImportWarning: _SixMetaPathImporter.find_spec() not found; falling back to find_module()

# %%
li.q # расположение квадрантов 1 НН, 2 LH, 3 LL, 4 HL
# Out:
# array([4, 4, 3, ..., 3, 3, 1])

# %%
# обозначаем случаи вне пространсвенной случайности
sig = 1 * (li.p_sim < 0.05)
sig.sum()
# Out:
# 1846

# %%
# определям квадранты булевым произведением

hotspot = 1 * (sig * li.q==1)
coldspot = 3 * (sig * li.q==3)
doughnut = 2 * (sig* li.q==2)
diamond = 4 * (sig * li.q==4)

# %%
# складываем все в один массив

spots = hotspot + coldspot + doughnut + diamond
spots
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# для каждого значения в массиве назначаем квадрант, полученный массив
# визуализируем категориальными значениями

spot_labels = ['0 нз', '1 хотспоты (спутники)', '2 ядра', '3 колдспоты', '4 испытывающие влияние 1 и 2']
labels = [spot_labels[i] for i in spots]
labels
# Out:
# ['0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '1 хотспоты (спутники)',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '3 колдспоты',
#  '0 нз',
#  '4 испытывающие влияние 1 и 2',
#  '3 колдспоты',
#  '4 испытывающие влияние 1 и 2',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '4 испытывающие влияние 1 и 2',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '1 хотспоты (спутники)',
#  '1 хотспоты (спутники)',
#  '1 хотспоты (спутники)',
#  '1 хотспоты (спутники)',
#  '1 хотспоты (спутники)',
#  '0 нз',
#  '1 хотспоты (спутники)',
#  '1 хотспоты (спутники)',
#  '0 нз',
#  '1 хотспоты (спутники)',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
#  '0 нз',
# ...

# %%
from matplotlib import colors 
hmap = colors.ListedColormap(['darkgrey', 'red', 'lightblue', 'blue','pink'])

f,ax = plt.subplots (1, figsize = (8.26,5.826))

highways.plot(ax=ax, color = 'grey', alpha = 0.2)
minsk.plot(ax=ax, color = 'lavender',alpha = .3, edgecolor = 'red')
buildings.plot(ax=ax, color='grey', alpha = 0.5)

m17.assign(cl=labels).plot(column='cl', categorical=True,
                           k=2, cmap=hmap,
                           markersize=10,
                           linewidth=0.1, ax=ax,
                           edgecolor='white',
                           legend=True,
                           legend_kwds ={'frameon':False,
                                         'loc':3,
                                         'ncol':1,
                                         'fontsize':9}, 
                          )
#ax.set_title('Локальный индекс пространсвенной ассоциации Морана',fontsize = 14)
#ax.legend(loc='lower left')
# scalebar = AnchoredSizeBar(ax.transData, 1, "1 Meter", 9)
ax.add_artist(ScaleBar(dx = 1,
                       location = 'lower right'
                       )) # 1 pixel = 1 м
# m17.legend(frameon=False, loc=0, ncol=2)
ax.set_axis_off()
#plt.show
plt.savefig('LISA.png', format='png', dpi=300)

# %% [markdown]
# ## 8) GWR

# %%
from mgwr.gwr import GWR, MGWR # моделирование ГВР и МГВР
from mgwr.sel_bw import Sel_BW # выбор полосы пропускания
from mgwr.utils import compare_surfaces, truncate_colormap
# Out:
# /home/milvari/EnvProj/myenv/lib/python3.10/site-packages/spreg/user_output.py:12: DeprecationWarning: Please use `csr_matrix` from the `scipy.sparse` namespace, the `scipy.sparse.csr` namespace is deprecated.
#   from scipy.sparse.csr import csr_matrix

# %% [markdown]
# ### 8.1. Подготовка исходных данных

# %%
# подготовка исходных данных
# выбор зависимой переменной, факторов

y = m17['price_m2_log'].values.reshape((-1,1))
x = m17[['rooms', 'area_total', 'year', 'house_type',
         'centre_dist', 'parks_dist','metro_dist', 'hospitals_dist',
         'schools_dist','transport_dist',
         'highways_dist','industrial_dist',
         #'heavy_dist',
         'floors',
         'foundat'
        ]].values

# получение списка координат
u = m17['x']
v = m17['y']
coords = list(zip(u,v))

# нормализация данных
x = (x-x.mean(axis=0))/x.std(axis=0)
y = y.reshape((-1,1))
y = (y-y.mean(axis=0)/y.std(axis=0))

# %% [markdown]
# ### 8.1. Калибровка ядра??

# %%
# калибровка ГВР-модели
# %time
gwr_selector = Sel_BW(coords, # координаты
                      y,x, # зависимая и независимые переменные
                      kernel = 'bisquare', # тип ядра
                      fixed = False).search(criterion = 'AICc',
                                            verbose = True)
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.15 µs
# Bandwidth:  1369.0 , score:  -3844.64
# Bandwidth:  2171.0 , score:  -3623.06
# Bandwidth:  873.0 , score:  -3978.13
# Bandwidth:  566.0 , score:  -4066.96
# Bandwidth:  377.0 , score:  -4121.14
# Bandwidth:  259.0 , score:  -4136.89
# Bandwidth:  187.0 , score:  -4081.12
# Bandwidth:  304.0 , score:  -4135.74
# Bandwidth:  232.0 , score:  -4129.54
# Bandwidth:  276.0 , score:  -4138.82
# Bandwidth:  287.0 , score:  -4136.62
# Bandwidth:  270.0 , score:  -4138.45
# Bandwidth:  281.0 , score:  -4138.60
# Bandwidth:  274.0 , score:  -4138.87
# Bandwidth:  272.0 , score:  -4138.57

# %%
print(gwr_selector)
# Out:
# 274.0

# %% [markdown]
# ### 8.3. ГВР-моделирование

# %%
gwr = GWR(coords,
          y, x,
          gwr_selector,
          kernel ='bisquare',
          fixed = False)
res = gwr.fit()

# %%
res.summary()
# Out:
# ...
# Model type                                                         Gaussian
# Number of observations:                                                3470
# Number of covariates:                                                    15
#
# Global Regression Results
# ---------------------------------------------------------------------------
# Residual sum of squares:                                             78.197
# Log-likelihood:                                                    1656.572
# AIC:                                                              -3283.144
# AICc:                                                             -3280.986
# BIC:                                                             -28086.651
# R2:                                                                   0.328
# Adj. R2:                                                              0.325
#
# Variable                              Est.         SE  t(Est/SE)    p-value
# ...

# %% [markdown]
# ### 8.4. Просмотр параметров модели - ошибки, их кластреризация и локальный коэффициент детерминации

# %%
m17['std_res'] = res.std_res;
m17['local_r2'] = res.localR2;
# Out:
# /home/milvari/EnvProj/myenv/lib/python3.10/site-packages/geopandas/geodataframe.py:1472: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /home/milvari/EnvProj/myenv/lib/python3.10/site-packages/geopandas/geodataframe.py:1472: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Moran I Test
np.random.seed(12345)
mi = esda.moran.Moran(m17['std_res'], kw)

# %%
sns.kdeplot(mi.sim, #(если n(перестановок)>0) вектор значений I для переставленных выборок
                    # моделируем нулевую гипотезу (случайные пространсвенные перестановки)
            shade=True)
plt.vlines(mi.I, 0, 20, color = 'r') # фактическое значение
plt.vlines(mi.EI, 0,20) # ожидаемое значение при допущении нормальности
plt.xlabel("Моран I")
plt.savefig('moran-std.png', dpi=300)
# Out:
# /tmp/ipykernel_49620/1608228912.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(mi.sim, #(если n(перестановок)>0) вектор значений I для переставленных выборок

# %%
mi.p_sim # --> отклоняем пространсвенную случайность

# (если перестановки>0)
# p-значение, основанное на перестановках
# H0: альтернатива пространственной случайности
# наблюдаемое I является экстремальным (высоким или низким)
# полученных на основе перестановок.
# Out:
# 0.001

# %%
f,ax = plt.subplots (1, figsize = (8.26,5.826)) # 2551x1795 - A5 (dpi-300)

highways.plot(ax=ax, color = 'grey', alpha = 0.2)
minsk.plot(ax=ax, color = 'c',alpha = .1, edgecolor = 'red')
buildings.plot(ax=ax, color='grey', alpha = 0.5)


m17.plot(column = 'std_res',
         ax=ax,
         scheme = 'StdMean',
         cmap = 'prism',
         markersize= 10,
         edgecolor = 'none',
         legend= True,
         legend_kwds = {'frameon':False,
                       'loc':3,
                        'ncol':1,
                       'fontsize':9}
        )
#ax.set_title('Цена за кв.м, г.Минск,2017 (Std.Mean)',fontsize = 14)
#ax.legend(loc='lower left')
# scalebar = AnchoredSizeBar(ax.transData, 1, "1 Meter", 9)
#ax.legend(frameon=False, loc=0, ncol=2)
ax.add_artist(ScaleBar(dx = 1, location = 'lower right')) # 1 pixel = 1 м

ax.set_axis_off()
#plt.show
plt.savefig('std_res_m17.png', format='png', dpi=300)

# %%
# классифицируем на пять квантилей
f,ax = plt.subplots (1, figsize = (8.26,5.826)) # 2551x1795 - A5 (dpi-300)

minsk.plot(ax=ax, color = 'c',alpha = .12, edgecolor = 'red',zorder=1)
highways.plot(ax=ax, color = 'grey', alpha = 0.2, linewidth =0.8, zorder=0)
buildings.plot(ax=ax, color='grey', alpha = 0.8, zorder=2)


m17.plot(column='local_r2', scheme="NaturalBreaks",
         k=5, cmap='Reds', linewidth=0.1, ax=ax, \
         edgecolor= 'k', 
         legend=True,
         legend_kwds = {'frameon':False,
                        'loc':3,
                        'ncol':2,
                        'fontsize':9},
         markersize=10,
         zorder = 3)
#ax.legend()
ax.set_axis_off()
ax.add_artist(ScaleBar(dx = 1,
                       location = 'lower right'
                      ),) # 1 pixel = 1 м
#plt.title("Пространсвенный лаг цена за м2 (Квантили)")
#plt.show()
plt.savefig('SpLag.png', dpi=300)

# %% [markdown]
# # GWR для однокомнатных квартир

# %%
# подготовка исходных данных
# выбор зависимой переменной, факторов

y = room1['price_m2_log'].values.reshape((-1,1))
x = room1[['area_total'
           ,'year'
           ,'house_type'
           ,'centre_dist'
           ,'parks_dist'
           ,'metro_dist'
           ,'hospitals_dist'
           ,'schools_dist'
           ,'transport_dist'
           ,'highways_dist'
           ,'industrial_dist'
           ,'heavy_dist'
           ,'floors' #'foundat'
        ]].values

# получение списка координат
u = room1['x']
v = room1['y']
coords = list(zip(u,v))

# нормализация данных
x = (x-x.mean(axis=0))/x.std(axis=0)
y = y.reshape((-1,1))
y = (y-y.mean(axis=0)/y.std(axis=0))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/EnvProj/myenv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File ~/EnvProj/myenv/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/EnvProj/myenv/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price_m2_log'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# калибровка ГВР-модели
# %time
sel = Sel_BW(coords, # координаты
                      y,x, # зависимая и независимые переменные
                      kernel = 'bisquare', # тип ядра
                      fixed = False).search(criterion = 'AICc')
# Out:
# CPU times: user 2 µs, sys: 3 µs, total: 5 µs
# Wall time: 8.34 µs

# %%
gwr = GWR(coords,
          y, x, 
          gwr_selector,
          kernel ='bisquare',
          fixed = False)
r1 = gwr.fit()

# %%
r1.summary();
# Out:
# ...
# Model type                                                         Gaussian
# Number of observations:                                                1005
# Number of covariates:                                                    14
#
# Global Regression Results
# ---------------------------------------------------------------------------
# Residual sum of squares:                                             15.475
# Log-likelihood:                                                     671.156
# AIC:                                                              -1314.312
# AICc:                                                             -1311.827
# BIC:                                                              -6835.053
# R2:                                                                   0.238
# Adj. R2:                                                              0.228
#
# Variable                              Est.         SE  t(Est/SE)    p-value
# ...

# %% [markdown]
# # GWR для двухкомнатных квартир

# %%
# подготовка исходных данных
# выбор зависимой переменной, факторов

y = room2['price_m2_log'].values.reshape((-1,1))
x = room2[['area_total'
           ,'year'
           ,'house_type'
           ,'centre_dist'
           ,'parks_dist'
           ,'metro_dist'
           ,'hospitals_dist'
           ,'schools_dist'
           ,'transport_dist'
           ,'highways_dist'
           ,'industrial_dist'
           ,'heavy_dist'
           ,'floors' #'foundat'
        ]].values

# получение списка координат
u = room2['x']
v = room2['y']
coords = list(zip(u,v))

# нормализация данных
x = (x-x.mean(axis=0))/x.std(axis=0)
y = y.reshape((-1,1))
y = (y-y.mean(axis=0)/y.std(axis=0))

# %%
# калибровка ГВР-модели
# %time
sel = Sel_BW(coords, # координаты
                      y,x, # зависимая и независимые переменные
                      kernel = 'bisquare', # тип ядра
                      fixed = False).search(criterion = 'AICc')
# Out:
# CPU times: user 1e+03 ns, sys: 1e+03 ns, total: 2 µs
# Wall time: 3.58 µs

# %%
gwr = GWR(coords,
          y, x, 
          gwr_selector,
          kernel ='bisquare',
          fixed = False)
r2 = gwr.fit()

# %%
r2.summary();
# Out:
# ...
# Model type                                                         Gaussian
# Number of observations:                                                1315
# Number of covariates:                                                    14
#
# Global Regression Results
# ---------------------------------------------------------------------------
# Residual sum of squares:                                             31.801
# Log-likelihood:                                                     581.373
# AIC:                                                              -1134.745
# AICc:                                                             -1132.376
# BIC:                                                              -9311.450
# R2:                                                                   0.245
# Adj. R2:                                                              0.238
#
# Variable                              Est.         SE  t(Est/SE)    p-value
# ...

# %%
#from scipy.spatial import Voronoi,voronoi_plot_2d
#from shapely.geometry import Point, MultiPolygon, Polygon

points_room2 = (list(zip(room2['x'], room2['y'])))
points_room2 = np.array(points_room2)

# %%
kw = Kernel(points_room2,
            fixed = False,
            k = 38) # адаптивные - 38 соседей

# %%
room2['std_res'] = r2.std_res;
# Out:
# /home/milvari/EnvProj/myenv/lib/python3.10/site-packages/geopandas/geodataframe.py:1472: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Moran I Test
np.random.seed(12345)
mi = esda.moran.Moran(room2['std_res'], kw)
mi.I
# Out:
# 0.02519416759642634

# %%
mi.EI # ожидаемое значение при допущении нормальности
# Out:
# -0.000676132521974307

# %%
max(mi.sim) # моделируем нулевую гипотезу (случайные пространсвенные перестановки)
# Out:
# 0.09188847900941297

# %%
sbn.kdeplot(mi.sim, #(если n(перестановок)>0) вектор значений I для переставленных выборок
            shade=True)
plt.vlines(mi.I, 0, 20, color = 'r')
plt.vlines(mi.EI, 0,20)
plt.xlabel("Моран I")
plt.savefig('moran-p.png', dpi=300)
# Out:
# /tmp/ipykernel_67771/2099604969.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sbn.kdeplot(mi.sim, #(если n(перестановок)>0) вектор значений I для переставленных выборок

# %%
mi.p_sim # --> отклоняем пространсвенную случайность

# (если перестановки>0)
# p-значение, основанное на перестановках
# H0: альтернатива пространственной случайности
# наблюдаемое I является экстремальным (высоким или низким)
# полученных на основе перестановок.
# Out:
# 0.001

# %% [markdown]
# # GWR для трехкомнатных квартир

# %%
# подготовка исходных данных
# выбор зависимой переменной, факторов

y = room3['price_m2_log'].values.reshape((-1,1))
x = room3[['area_total'
           ,'year'
           ,'house_type'
           ,'centre_dist'
           ,'parks_dist'
           ,'metro_dist'
           ,'hospitals_dist'
           ,'schools_dist'
           ,'transport_dist'
           ,'highways_dist'
           ,'industrial_dist'
           ,'heavy_dist'
           ,'floors' #'foundat'
        ]].values

# получение списка координат
u = room3['x']
v = room3['y']
coords = list(zip(u,v))

# нормализация данных
x = (x-x.mean(axis=0))/x.std(axis=0)
y = y.reshape((-1,1))
y = (y-y.mean(axis=0)/y.std(axis=0))

# %%
# калибровка ГВР-модели
# %time
sel = Sel_BW(coords, # координаты
                      y,x, # зависимая и независимые переменные
                      kernel = 'bisquare', # тип ядра
                      fixed = False).search(criterion = 'AICc')
# Out:
# CPU times: user 1e+03 ns, sys: 3 µs, total: 4 µs
# Wall time: 9.06 µs
# Bandwidth:  505.0 , score:  -1024.71
# Bandwidth:  775.0 , score:  -962.32
# Bandwidth:  338.0 , score:  -1058.31
# Bandwidth:  235.0 , score:  -1066.20
# Bandwidth:  171.0 , score:  -1050.72
# Bandwidth:  274.0 , score:  -1065.72
# Bandwidth:  210.0 , score:  -1063.56
# Bandwidth:  250.0 , score:  -1066.45
# Bandwidth:  259.0 , score:  -1066.46
# Bandwidth:  265.0 , score:  -1066.14
# Bandwidth:  256.0 , score:  -1066.40
# Bandwidth:  262.0 , score:  -1066.53
# Bandwidth:  263.0 , score:  -1066.59
# Bandwidth:  264.0 , score:  -1066.20

# %%
gwr = GWR(coords,
          y, x, 
          gwr_selector,
          kernel ='bisquare',
          fixed = False)
r3 = gwr.fit()

# %%
r3.summary();
# Out:
# ...
# Model type                                                         Gaussian
# Number of observations:                                                1212
# Number of covariates:                                                    14
#
# Global Regression Results
# ---------------------------------------------------------------------------
# Residual sum of squares:                                             33.601
# Log-likelihood:                                                     453.050
# AIC:                                                               -878.100
# AICc:                                                              -875.699
# BIC:                                                              -8472.232
# R2:                                                                   0.287
# Adj. R2:                                                              0.280
#
# Variable                              Est.         SE  t(Est/SE)    p-value
# ...

# %%
#from scipy.spatial import Voronoi,voronoi_plot_2d
#from shapely.geometry import Point, MultiPolygon, Polygon

points_room3 = (list(zip(room3['x'], room3['y'])))
points_room3 = np.array(points_room3)

# %%
kw = Kernel(points_room1,
            fixed = False,
            k = 18) # адаптивные - 35 соседей
kw.transform = 'r'
# Out:
# /home/milvari/EnvProj/myenv/lib/python3.10/site-packages/libpysal/weights/weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#   warnings.warn(message)

# %%
room1['std_res'] = r1.std_res;
# Out:
# /home/milvari/EnvProj/myenv/lib/python3.10/site-packages/geopandas/geodataframe.py:1472: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Moran I Test
np.random.seed(12345)
mi = esda.moran.Moran(room1['std_res'], kw)
mi.I
# Out:
# 0.09891592346442284

# %%
mi.EI # ожидаемое значение при допущении нормальности
# Out:
# -0.0008865248226950354

# %%
max(mi.sim) # моделируем нулевую гипотезу (случайные пространсвенные перестановки)
# Out:
# 0.17257250609564706

# %%
sbn.kdeplot(mi.sim, #(если n(перестановок)>0) вектор значений I для переставленных выборок
            shade=True)
plt.vlines(mi.I, 0, 20, color = 'r')
plt.vlines(mi.EI, 0,20)
plt.xlabel("Моран I")
plt.savefig('moran-p.png', dpi=300)
# Out:
# /tmp/ipykernel_67771/2099604969.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sbn.kdeplot(mi.sim, #(если n(перестановок)>0) вектор значений I для переставленных выборок

# %%
mi.p_sim # --> отклоняем пространсвенную случайность

# (если перестановки>0)
# p-значение, основанное на перестановках
# H0: альтернатива пространственной случайности
# наблюдаемое I является экстремальным (высоким или низким)
# полученных на основе перестановок.
# Out:
# 0.001

# %% [markdown]
# ## DBSCAN

# %%
import contextily as cx
from libpysal.cg.alpha_shapes import alpha_shape_auto

import sys
sys.path.append('../')
try:
    from esda.adbscan import ADBSCAN, get_cluster_boundary, remap_lbls
except:
    print("Import from local folder...")
    import sys
    sys.path.append("../esda")
    from adbscan import ADBSCAN, get_cluster_boundary, remap_lbls

# %%
m17.shape[0] * 0.01 #1% of the overall sample size 
                    # for the min_samples parameter
# Out:
# 59.06

# %%
# pull out the projected coords into separate colunms
m17['X']=m17.geometry.x
m17['Y']=m17.geometry.y

m17.head()
# Out:
#          rooms            street_nam  house_numb  building_n  price_m2  \
# FID_
# 5399.0     2.0         Тикоцкого ул.         4.0         0.0     741.0
# 11230.0    4.0             Мавра ул.        25.0         0.0     741.0
# 9305.0     2.0       Шпилевского ул.        52.0         0.0     743.0
# 4084.0     2.0         Васнецова ул.         9.0         0.0     750.0
# 8637.0     3.0  Радиаторный 2-й пер.        20.0         0.0     752.0
#
#          area_total    year house_type          x          y  \
# FID_
# 5399.0         49.9  1978.0          п  27.626329  53.957141
# 11230.0       103.9  2014.0          п  27.490928  53.897980
# 9305.0         74.0  2014.0          п  27.565100  53.846600
# 4084.0         44.0  1962.0          п  27.617769  53.873171
# 8637.0        166.2  2010.0         сб  27.482465  53.925386
#
#                                geometry  b  k  kb  m  p  sb              X  \
# FID_
# ...

# %%
# we will use 500 m radious - eps (at least about 25 properties per sq)

# run ahead
# %time
adbs = ADBSCAN(600, 60, pct_exact=0.5, reps=10, keep_solus=True)
np.random.seed(1234)
adbs.fit(m17)
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 8.82 µs
# ADBSCAN(eps=600, keep_solus=True, min_samples=60, pct_exact=0.5, reps=10)

# %%
ax = m17.assign(lbls=adbs.votes['lbls']).plot(column='lbls',
                                            categorical=True,
                                            markersize=2.5,
                                            figsize=(12,12)
                                            )
cx.add_basemap(ax, crs=m17.crs.to_string())

# %%
polys = get_cluster_boundary(adbs.votes['lbls'],
                             m17
                             ,crs=m17.crs)

# %%
# plot those
ax = polys.plot(alpha=.5, color='m')
cx.add_basemap(ax, crs=polys.crs.to_string())
