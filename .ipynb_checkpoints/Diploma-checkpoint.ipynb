# %%
# Импорт библиотек

import os
import osmnx as ox # экспорт данных осм
import numpy as np # работа с массивами
import scipy # статистический
import pandas as pd # серии и фреймы данных
import shapely # работа с геометрией
import geopandas as gpd # геодатафреймы и геосерии
import libpysal as lps # пространсвенная эконометрика
from libpysal.weights import *
import matplotlib.pyplot as plt # визуализация
from matplotlib_scalebar.scalebar import ScaleBar
import mapclassify as mc# методы символизации
# %matplotlib inline

# %% [markdown]
# ## Работа с исходными данными

# %%
# получение текущей рабочей директории
print(os.getcwd())

# изменение директории Minsk_2017
os.chdir('Minsk_2017');
# Out:
# /home/milvari/EnvProj/myenv/Minsk/Minsk_2017
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [32], line 5
#       2 print(os.getcwd())
#       4 # изменение директории Minsk_2017
# ----> 5 os.chdir('Minsk_2017')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Minsk_2017'

# %%
# чтение основного геодатафрейма данных
# вторичная недвижимость, Минск, 2017 год
m17 = gpd.read_file('Minsk_flat_price.shp')
m17.head()

# %%
# Работа с системой координат

local_crs = m17.estimate_utm_crs() 
m17.to_crs(local_crs, inplace=True)
m17.crs

# %%
# Выявление формы датафрейма --> (строки, столбцы)
m17.shape

# %%
# Просмотр структуры датафрейма

m17.info()

# %%
# Проверка уникальности ключа FID_

len(m17) == len(m17['FID_'].unique())

# %%
# Удаление избыточных атрибутов, переименование

m17.drop(['Admi_housi','town_name','price',
         'date_recep','agency','code','priority','counter', 'Id_me'],
         axis=1,
         inplace = True
        );
m17.rename(columns = {'building_y':'year'}, inplace=True);

# %%
# Выявление пустых значений (Null)

m17.isnull().sum()

# %%
# Удаление Null-значений, повторная проверка

m17.dropna(axis=0, inplace=True);
m17.isnull().sum()

# %%
# Проверка данных на нормальность распределения
# Ни одна из величин не имеет нормального распределения, что справедливо
# для такой большой выборки

for col in m17.select_dtypes(include=np.number):
    stat,p = scipy.stats.normaltest(m17[col])
    alpha = 0.05
    print("p = {:g}".format(p))

    if p < alpha:  # null hypothesis: x comes from a normal distribution
        print("The % has not a normal distribution."%col)
    else:
        print("The % has a normal distribution."%col)

# %%
# Тип дома - качественный атрибут массива (тип строчный), 
# для дальнейшей обработки каждое уникальное значение
# станет бинарным атрибутом

# просмотр уникальных значений

vc = m17['house_type'].value_counts() # --> 9
vc

# %%
# Выберем те значения, которые встречаются менее 100 раз
to_remove = vc[vc <= 100].index

# Преобразуем массив
m17 = m17[~m17.house_type.isin(to_remove)]

# Просмотрим значения типа дома вновь
m17['house_type'].value_counts()

# %%
# преобразуем категориальную переменные в индикаторные

m17 = m17.join(pd.get_dummies(m17.house_type));

# %%
m17.rename(columns = {'п':'p',
                      'кб':'kb',
                      'м':'m',
                      'б':'b',
                      'сб':'sb',
                      'к':'k'}, inplace=True);

# %%
m17.info()

# %%
# Описательная статистика:
# число объектов, среднее значение, стандартное отклонение, минимум, максимум,квантили 
m17.describe()

# %%
# Гистограмма распределения зависимой переменной - цены за м2
# Асимметрична, унимодальна

prices = m17['price_m2'].values
plt.hist(prices, bins=40, color='m')
plt.ylabel('Probability')
plt.xlabel('Data')

# %%
np.arange(0.94,1)

# %%
# Работа с выбросами - просмотрим квантили от 0,95 до 0,99
qua = []
for i in np.arange(0.94,1.0, 0.01):
    q = m17['price_m2'].quantile(i)
    qua.append(q)
plt.plot(np.arange(0.94,1.0, 0.01),qua) # --> выбираем квантиль 0.99

# %%
# Отчистим массив, ограничевшись кватилем 99%

m17 = m17[m17['price_m2']<m17['price_m2'].quantile(0.99)]

# %%
# Гистограмма распределения 

prices = m17['price_m2'].values
plt.hist(prices, bins=30)
plt.ylabel('Probability')
plt.xlabel('Data')

# %%
# Проверка на нормальность 

stat,p = scipy.stats.normaltest(m17['price_m2'])
alpha = 0.05
print("p = {:g}".format(p)) # --> отклоняем нулевую гипотезу о нормальности

# %% [markdown]
# m17.set_index('FID_',inplace=True)

# %%
m17.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 5788 entries, 0 to 5843
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FID_        5788 non-null   float64
#  1   rooms       5788 non-null   float64
#  2   street_nam  5788 non-null   object
#  3   house_numb  5788 non-null   float64
#  4   building_n  5788 non-null   float64
#  5   price_m2    5788 non-null   float64
#  6   area_total  5788 non-null   float64
#  7   year        5788 non-null   float64
#  8   house_type  5788 non-null   object
#  9   x           5788 non-null   float64
#  10  y           5788 non-null   float64
#  11  geometry    5788 non-null   geometry
#  12  b           5788 non-null   uint8
#  13  k           5788 non-null   uint8
#  14  kb          5788 non-null   uint8
#  15  m           5788 non-null   uint8
#  16  p           5788 non-null   uint8
#  17  sb          5788 non-null   uint8
# dtypes: float64(9), geometry(1), object(2), uint8(6)
# memory usage: 621.8+ KB

# %% [markdown]
# ## Получение данных ОСМ для анализа и визуализации

# %% [markdown]
# ### 1) Атрибуты близости

# %%
# Определяем место (Минск, Беларусь) и повторно - проекционную систему координат
place = 'Minsk, Belarus'
local_crs = m17.estimate_utm_crs() # WGS 84 / UTM zone 35N

# %%
# Интерактивная проверка инструментом геокодирования
gpd.tools.geocode(place).explore(                              
         tiles="Stamen Watercolor" # use "CartoDB positron" tiles
                                )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0aa6974d503fecb2b1d5ff04813126f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0aa6974d503fecb2b1d5ff04813126f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f0aa6974d503fecb2b1d5ff04813126f = L.map(
#                 &quot;map_f0aa6974d503fecb2b1d5ff04813126f&quot;,
#                 {
#                     center: [53.9024716, 27.5618225],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f0aa6974d503fecb2b1d5ff04813126f);
#
#
#
#
#
#             var tile_layer_4a82b7ba11ee1bddc8b1dcc6924c62bc = L.tileLayer(
#                 &quot;https://stamen-tiles-a.a.ssl.fastly.net/watercolor/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e \u0026mdash; Map data \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 16, &quot;maxZoom&quot;: 16, &quot;minZoom&quot;: 1, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f0aa6974d503fecb2b1d5ff04813126f);
#
#
#             map_f0aa6974d503fecb2b1d5ff04813126f.fitBounds(
#                 [[53.9024716, 27.5618225], [53.9024716, 27.5618225]],
#                 {}
#             );
#
#
#         function geo_json_5dd7f61ed420f2806fdaba8185885f8c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5dd7f61ed420f2806fdaba8185885f8c_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5dd7f61ed420f2806fdaba8185885f8c_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_5dd7f61ed420f2806fdaba8185885f8c_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5dd7f61ed420f2806fdaba8185885f8c_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_5dd7f61ed420f2806fdaba8185885f8c.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5dd7f61ed420f2806fdaba8185885f8c_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5dd7f61ed420f2806fdaba8185885f8c = L.geoJson(null, {
#                 onEachFeature: geo_json_5dd7f61ed420f2806fdaba8185885f8c_onEachFeature,
#
#                 style: geo_json_5dd7f61ed420f2806fdaba8185885f8c_styler,
#                 pointToLayer: geo_json_5dd7f61ed420f2806fdaba8185885f8c_pointToLayer
#         });
#
#         function geo_json_5dd7f61ed420f2806fdaba8185885f8c_add (data) {
#             geo_json_5dd7f61ed420f2806fdaba8185885f8c
#                 .addData(data)
#                 .addTo(map_f0aa6974d503fecb2b1d5ff04813126f);
#         }
#             geo_json_5dd7f61ed420f2806fdaba8185885f8c_add({&quot;bbox&quot;: [27.5618225, 53.9024716, 27.5618225, 53.9024716], &quot;features&quot;: [{&quot;bbox&quot;: [27.5618225, 53.9024716, 27.5618225, 53.9024716], &quot;geometry&quot;: {&quot;coordinates&quot;: [27.5618225, 53.9024716], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;address&quot;: &quot;\u041c\u0438\u043d\u0441\u043a, \u0411\u0435\u043b\u0430\u0440\u0443\u0441\u044c&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#     geo_json_5dd7f61ed420f2806fdaba8185885f8c.bindTooltip(
#     function(layer){
#     let div = L.DomUtil.create(&#x27;div

# %% [markdown]
# m = ox.graph_from_place(place)

# %% [markdown]
# fix, ax = ox.plot_graph(m,
#                        figsize=(10,10),
#                        bgcolor = 'white',
#                        node_color = 'black',
#                        node_size = 3,
#                        node_alpha = 0.3,
#                        edge_color = 'black',
#                        edge_linewidth = 0.1,
#                        edge_alpha = 0.3,
#                        show=False,
#                        close=False)
# m17.plot(column = 'price_m2', ax=ax,
#          scheme = 'StdMean',cmap = 'spring',
#          markersize=5, edgecolor = 'k',legend = True)
#
# set title, legend_name, scale..........

# %% [markdown]
# mw = ox.graph_from_place(place,network_type='walk')

# %% [markdown]
# fix, ax = ox.plot_graph(mw,
#                      figsize=(10,10),
#                       bgcolor = 'white',
#                        node_color = 'black',
#                        node_size = 3,
#                        node_alpha = 0.3,
#                        edge_color = 'black',
#                        edge_linewidth = 0.1,
#                        edge_alpha = 0.3,
#                        show=False,
#                        close=False)

# %%
# Получение данных ОСМ по обозначаемым тегам
# %time
parks = ox.geometries.geometries_from_place(place,
                                           tags = {'leisure':'park',
                                                  'natural':'wood'});

metro = ox.geometries.geometries_from_place(place,
                                           tags = {'railway':'station',
                                                  'railway':'subway_entrance'}
                                           );
hospitals = ox.geometries.geometries_from_place(place,
                                           tags = {'amenity':'hospital',
                                                  'amenity':'doctors',
                                                  'amenity':'clinic'
                                                  }
                                           );
schools = ox.geometries.geometries_from_place(place,
                                           tags = {'amenity':'school'}
                                           );
transport = ox.geometries.geometries_from_place(place,
                                           tags = {'public_transport':'stop_position'}
                                           ); 
highways = ox.geometries.geometries_from_place(place,
                                           tags = {'highway':'primary'}
                                           );
industrial = ox.geometries.geometries_from_place(place,
                                           tags = {'landuse':'industrial'}
                                           );
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.25 µs

# %%
# Удаляем все избыточные атрибуты - все, кроме столбца геометрии
# (через цикл не идет :-( )
parks=parks[['geometry']]
metro = metro[['geometry']]
hospitals = hospitals[['geometry']]
schools = schools[['geometry']]
transport = transport[['geometry']]
highways = highways[['geometry']]
industrial = industrial[['geometry']]

# %% [markdown]
# for i in osm_is:
#     i=i[['geometry']]
#     i.to_postgis(str(i), con=engine)

# %%
# Работа с проекцией
parks.to_crs(local_crs, inplace=True)
metro.to_crs(local_crs, inplace=True)
hospitals.to_crs(local_crs, inplace=True)
schools.to_crs(local_crs, inplace=True)
transport.to_crs(local_crs, inplace=True)
highways.to_crs(local_crs, inplace=True)
industrial.to_crs(local_crs, inplace=True)

# %% [markdown]
# ### 2) Получение зданий и границы города для визуализации

# %%
minsk = ox.geometries.geometries_from_place(query = {'city':'Minsk'},
                                            tags  = {
                                                    'admin_level': '4',
                                                    'name':'Минск'
                                                    });

# %%
# фильтрация по тэгу-тип и присвоение первичного ключа

minsk = minsk[minsk['type']=='boundary'].reset_index(drop=True)
minsk = minsk[['geometry']].to_crs(local_crs)
minsk['uID'] = range(len(minsk))
minsk = minsk.loc[minsk['uID']==0]

# %%
# в результате --> один объект - мультиполигон
minsk
# Out:
#                                             geometry  uID
# 0  MULTIPOLYGON (((558532.867 5970840.893, 558517...    0

# %%
# Разобъем его (взорвем) на полигоны
minsk = minsk.explode(index_parts=True)
minsk
# Out:
#      uID                                           geometry
# 0 0    0  POLYGON ((558532.867 5970840.893, 558517.699 5...
#   1    0  POLYGON ((524818.174 5969095.911, 524755.121 5...
#   2    0  POLYGON ((566076.512 5975311.058, 566344.933 5...

# %%
# Получим наибольший из полигонов - он и будет границей Минска в пределах кольца 
minsk = max(minsk['geometry'], key=lambda a: a.area)

# %%
# Обернем геометрию границы в геодатафрейм
minsk = gpd.GeoDataFrame(index=[0],
                        crs = 'EPSG:32635',
                        geometry = [minsk])
minsk
# Out:
#                                             geometry
# 0  POLYGON ((524818.174 5969095.911, 524755.121 5...

# %%
buildings = ox.geometries.geometries_from_place(place,
                                           tags = {'building':'yes'
                                                   });

# %%
# фильтрация по geom.type=='Polygon'
buildings = buildings[buildings.geom_type=='Polygon'].reset_index(drop=True)

# определение проекционной системы
buildings = buildings[['geometry']].to_crs(local_crs)

# обрезание зданий по границе
buildings = gpd.clip(buildings, minsk)

# %% [markdown]
# ## SQLAlchemy - для работы с SQLite
#
# ### необходимо установить движок DBAPI (для postgres - это psycopg2)

# %%
from sqlalchemy import create_engine

# %%
# создание движка для подключения к базе данных

engine = create_engine("postgresql+psycopg2://postgres:malica@localhost:5432/geo")

# %%
# подключение к базе данных
engine.connect()

# %%
# экспорт необходимых данных в БД - gpf.to_postgis

# %% [markdown]
# parks.to_postgis('parks',con=engine)
# metro.to_postgis('metro',con=engine)
# hospitals.to_postgis('hospitals',con=engine)
# schools.to_postgis('schools',con=engine)
# transport.to_postgis('transport',con=engine)
# highways.to_postgis('highways',con=engine)
# industrial.to_postgis('industrial',con=engine)
# m17.to_postgis('property',con=engine)

# %%
# --------- SQL-запрос--------------------------

# %%
# импорт таблицы из БД - gpd.from_postgis
distances = gpd.GeoDataFrame.from_postgis('distances',
                                          con=engine,
                                          geom_col='geometry')
# Out:
# /home/milvari/EnvProj/myenv/lib/python3.10/site-packages/pandas/io/sql.py:581: SAWarning: Did not recognize type 'geometry' of column 'geometry'
#   pandas_sql.meta.reflect(bind=pandas_sql.connectable, only=[sql])

# %%
# соединение таблицы с датафреймом (слияние с бесконечно вечным)
m17 = m17.join(distances.set_index('FID_'), on='FID_',
               how='left', lsuffix='_left', rsuffix='_right',
              sort='FID_')

# %%
m17.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 5788 entries, 3839 to 3712
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FID_             5788 non-null   float64
#  1   rooms            5788 non-null   float64
#  2   street_nam       5788 non-null   object
#  3   house_numb       5788 non-null   float64
#  4   building_n       5788 non-null   float64
#  5   price_m2         5788 non-null   float64
#  6   area_total       5788 non-null   float64
#  7   year             5788 non-null   float64
#  8   house_type       5788 non-null   object
#  9   x                5788 non-null   float64
#  10  y                5788 non-null   float64
#  11  geometry_left    5788 non-null   geometry
#  12  b                5788 non-null   uint8
#  13  k                5788 non-null   uint8
#  14  kb               5788 non-null   uint8
#  15  m                5788 non-null   uint8
#  16  p                5788 non-null   uint8
#  17  sb               5788 non-null   uint8
#  18  geometry_right   5788 non-null   geometry
#  19  parks_dist       5788 non-null   float64
#  20  metro_dist       5788 non-null   float64
#  21  hospitals_dist   5788 non-null   float64
#  22  schools_dist     5788 non-null   float64
#  23  transport_dist   5788 non-null   float64
#  24  highways_dist    5788 non-null   float64
#  25  industrial_dist  5788 non-null   float64
# dtypes: float64(16), geometry(2), object(2), uint8(6)
# memory usage: 983.5+ KB

# %%
# Работа с столбцом геометрии
m17.drop(['geometry_left'],
         axis=1,
         inplace = True
        )
m17.rename(columns = {'geometry_right':'geometry'}, inplace=True)
m17.set_geometry('geometry');

# %%
# Просмотр конечного датафрейма
m17.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 5788 entries, 3839 to 3712
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FID_             5788 non-null   float64
#  1   rooms            5788 non-null   float64
#  2   street_nam       5788 non-null   object
#  3   house_numb       5788 non-null   float64
#  4   building_n       5788 non-null   float64
#  5   price_m2         5788 non-null   float64
#  6   area_total       5788 non-null   float64
#  7   year             5788 non-null   float64
#  8   house_type       5788 non-null   object
#  9   x                5788 non-null   float64
#  10  y                5788 non-null   float64
#  11  b                5788 non-null   uint8
#  12  k                5788 non-null   uint8
#  13  kb               5788 non-null   uint8
#  14  m                5788 non-null   uint8
#  15  p                5788 non-null   uint8
#  16  sb               5788 non-null   uint8
#  17  geometry         5788 non-null   geometry
#  18  parks_dist       5788 non-null   float64
#  19  metro_dist       5788 non-null   float64
#  20  hospitals_dist   5788 non-null   float64
#  21  schools_dist     5788 non-null   float64
#  22  transport_dist   5788 non-null   float64
#  23  highways_dist    5788 non-null   float64
#  24  industrial_dist  5788 non-null   float64
# dtypes: float64(16), geometry(1), object(2), uint8(6)
# memory usage: 938.3+ KB

# %% [markdown]
# ## Пространсвенная эконометрика

# %% [markdown]
# ### 1) Просмотрим распределение цен по Минску, при помощи простой визуализации

# %%
from mpl_toolkits.axes_grid1.anchored_artists import AnchoredSizeBar

# %%
f,ax = plt.subplots (1, figsize = (8.26,5.826)) # 2551x1795 - A5 (dpi-300)

minsk.plot(ax=ax, color = 'c',alpha = .1, edgecolor = 'red')
highways.plot(ax=ax, color = 'grey', alpha = 0.2)
buildings.plot(ax=ax, color='grey', alpha = 0.5)


m17.plot(column = 'price_m2',
         ax=ax,
         scheme = 'StdMean',
         cmap = 'plasma',
         markersize= 8,
         edgecolor = 'none',
         legend= True)
ax.set_title('Цена за кв.м, г.Минск,2017 (Std.Mean)',
             fontsize = 14)
#ax.legend(loc='lower left')
# scalebar = AnchoredSizeBar(ax.transData, 1, "1 Meter", 9)
ax.add_artist(ScaleBar(dx = 1,
                       location = 'lower left'
                      ),) # 1 pixel = 1 м
# m17.legend(frameon=False, loc=0, ncol=2)
ax.set_axis_off()
plt.show
plt.savefig('StdMean.png', format='png', dpi=300)

# %% [markdown]
# ## Пространственные весы (выбран Kernel weights - весы расстояния, отражающие первый закон Тоблера) - выражают феномен соседства (spatial similarity)

# %%
# Сontinuously valued weights
# to reflect Tobler’s first law [Tob70] in a more direct way:
# observations that are close to a unit have larger weights
# than more distant observations.

# reflect the case where similarity/spatial proximity
# is assumed or expected to decay with distance

# The essence of kernel weights is
# that the weight between observations i and j is based on
# their distance,
# but it is further modulated by a kernel function
#with certain properties

# %%
#from scipy.spatial import Voronoi,voronoi_plot_2d
#from shapely.geometry import Point, MultiPolygon, Polygon

points = (list(zip(m17['x'], m17['y'])))
points = np.array(points)

# %%
kw = Kernel(points,fixed = False,
           k = 20)
# Out:
# /home/milvari/EnvProj/myenv/lib/python3.10/site-packages/libpysal/weights/weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#   warnings.warn(message)

# %%
kw.neighbors [0] # expressing neighboor relationships
             # by expressing the focal observation on the left and right
# Out:
# [0,
#  2,
#  1,
#  2539,
#  6,
#  5787,
#  3,
#  5784,
#  5779,
#  3814,
#  5279,
#  157,
#  5341,
#  5785,
#  1353,
#  2590,
#  158,
#  1354,
#  2574,
#  23,
#  3874]

# %%
c = kw.cardinalities;
pd.Series(c).plot.hist(color="k");

# %%
kw.weights[0]
# Out:
# [1.0,
#  0.8852309071312294,
#  0.8852309071312294,
#  0.772018023296428,
#  0.7437155405869662,
#  0.743368506630453,
#  0.7346254684020253,
#  0.6469470837322286,
#  0.6352009017677367,
#  0.6130925546453667,
#  0.32959108574163143,
#  0.3185309621711846,
#  0.308726524455455,
#  0.3057846375411407,
#  0.29554140242378424,
#  0.23338637693137831,
#  0.2123913442426142,
#  0.15990057982527417,
#  0.03930955885410381,
#  0.01843770159598357,
#  9.99999899553572e-08]

# %%
print(kw.nonzero)
print(kw.pct_nonzero) # equal to 100*(w.s0/w.n^2)
# Out:
# 121548
# 0.36281962681409813

# %%
kw.s0 # number of joins
# Out:
# 48065.30936091405

# %% [markdown]
# ## Атрибутивное сходство (Atribute similarity) - сглаживаем пространсвенным лагом

# %%
kw.transform = 'r'# весовая трансформация,'r' - построчная,
                  # 'B' - бинарная, 'D' - дважды-стандартизированная,
                  # 'U' - без, 'V'-стабилизирующий дисперсию
# определяем зависимую переменную
y = m17['price_m2']

# %%
# Модель пространсвенного лага - это модель, описывающая эффект
# ПРОСТРАНСТВЕННОЙ ЗАВИСИМОСТИ
# Пространсвенный лаг - это взвешенное среднее соседствующих значений
# зависимой переменной, сумма произведений матрицы весов на вектор наблюдений

# Более гладкая в сравнении с скользящим средним
ylag = lps.weights.lag_spatial(kw,y)

# %%
plt.plot(ylag, linewidth =0.5) # --> видим 5 частей

# %%
# классифицируем на пять квантилей

ylagq5 = mc.Quantiles(ylag, k=5)
ylagq5
# Out:
# Quantiles
#
#      Interval        Count
# --------------------------
# [ 941.53, 1112.16] |  1158
# (1112.16, 1164.80] |  1158
# (1164.80, 1232.79] |  1158
# (1232.79, 1360.28] |  1156
# (1360.28, 1883.06] |  1158

# %%
f,ax = plt.subplots (1, figsize = (8.26,5.826)) # 2551x1795 - A5 (dpi-300)

minsk.plot(ax=ax, color = 'c',alpha = .1, edgecolor = 'red')
highways.plot(ax=ax, color = 'grey', alpha = 0.2)
buildings.plot(ax=ax, color='grey', alpha = 0.5)


m17.assign(cl=ylagq5.yb).plot(column='cl', categorical=True,\
                            k=5, cmap='GnBu', linewidth=0.1, ax=ax, \
                            edgecolor= 'k', legend=True)
ax.set_axis_off()
ax.add_artist(ScaleBar(dx = 1,
                       location = 'lower left'
                      ),) # 1 pixel = 1 м
plt.title("Spatial Lag Prise per m2 (Quintiles)")
plt.show()
plt.savefig('SpLag.png', format='png', dpi=300)

# %% [markdown]
# ## Пространсвенная автокорреляция - про взаимодействие (отражает общую схожесть)

# %% [markdown]
# ### H0: пространсвенная случайность - отсутсвие любого паттерна

# %% [markdown]
# ### 1) Бинарный случай

# %%
# Посмотрели на медиану зависимой переменной
y.median()
# Out:
# 1194.0

# %%
# Выбрали значения выше медианы
yb = y > y.median()
sum(yb)
# Out:
# 2885

# %%
labels = ["0 Below", "1 Above"]
yb = [labels[i] for i in 1*yb]

# %%
m17['yb'] = yb
m17.head()
# Out:
#       FID_  rooms              street_nam  house_numb  building_n  price_m2  \
# 3839   0.0    1.0  Героев 120 Дивизии ул.        27.0         0.0    1284.0
# 4157   1.0    1.0  Героев 120 Дивизии ул.        29.0         0.0    1327.0
# 5360   3.0    1.0  Героев 120 Дивизии ул.        29.0         0.0    1633.0
# 2872   4.0    1.0  Героев 120 Дивизии ул.        33.0         0.0    1190.0
# 81     5.0    1.0            Гуртьева ул.        14.0         0.0     854.0
#
#       area_total    year house_type          x  ...  sb  \
# 3839        49.0  2012.0          п  27.723200  ...   0
# 4157        49.0  2012.0          п  27.723900  ...   0
# 5360        49.0  2013.0          п  27.723900  ...   0
# 2872        47.0  2012.0          п  27.724920  ...   0
# 81          48.0  1970.0         сб  27.741279  ...   1
#
#                             geometry  parks_dist   metro_dist  hospitals_dist  \
# 3839  POINT (547470.348 5977366.418)  135.390274  2222.593697      800.867506
# 4157  POINT (547516.863 5977311.258)   88.845893  2277.003627      869.830404
# 5360  POINT (547516.863 5977311.258)   88.845893  2277.003627      869.830404
# 2872  POINT (547584.383 5977256.426)   60.658296  2352.969795      948.045267
# 81    POINT (548638.498 5979149.329)   23.739358  3673.255016      188.533131
#
#       schools_dist  transport_dist highways_dist  industrial_dist      yb
# 3839     23.757774      271.166518   1510.844907       310.476462  1 High
# 4157     54.368808      204.024323   1562.897062       238.669685  1 High
# 5360     54.368808      204.024323   1562.897062       238.669685  1 High
# 2872     62.013553      128.830758   1615.929085       155.229325   0 Low
# 81     1964.565168      302.368797   1052.783426       190.767202   0 Low
#
# [5 rows x 26 columns]

# %%
f,ax = plt.subplots (1, figsize = (8.26,5.826))

minsk.plot(ax=ax, color = 'lightcoral',alpha = .2, edgecolor = 'red')
highways.plot(ax=ax, color = 'grey', alpha = 0.2)
buildings.plot(ax=ax, color='grey', alpha = 0.5)

m17.plot(column='yb', cmap='binary',
         ax=ax,
         edgecolor='grey',
         linewidth = 0.09,
         legend=True,
         markersize = 8)

ax.add_artist(ScaleBar(dx = 1,
                       location = 'lower left'
                      ),) # 1 pixel = 1 м
plt.title("Prices above/below the median")
ax.set_axis_off()
plt.show()
plt.savefig('Binary.png', format='png', dpi=300)

# %% [markdown]
# ### 2) Непрерывный случай

# %%
# Moran I Test
import esda # работа с автокорреляцией
import seaborn as sbn

np.random.seed(12345)
mi = esda.moran.Moran(y, kw)
mi.I
# Out:
# <frozen importlib._bootstrap>:914: ImportWarning: _SixMetaPathImporter.find_spec() not found; falling back to find_module()
# 0.4749839307211287

# %%
mi.EI # ожидаемое значение при допущении нормальности
# Out:
# -0.00017280110592707794

# %%
max(mi.sim) # моделируем нулевую гипотезу (случайные пространсвенные перестановки)
# Out:
# 0.1400292132791722

# %%
sbn.kdeplot(mi.sim, #(если n(перестановок)>0) вектор значений I для переставленных выборок
            shade=True)
plt.vlines(mi.I, 0, 20, color = 'r')
plt.vlines(mi.EI, 0,20)
plt.xlabel("Moran's I")
# Out:
# /tmp/ipykernel_7124/3804118019.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sbn.kdeplot(mi.sim, #(если n(перестановок)>0) вектор значений I для переставленных выборок
# Text(0.5, 0, "Moran's I")

# %%
mi.p_sim # --> отклоняем пространсвенную случайность

# (если перестановки>0)
# p-значение, основанное на перестановках
# H0: альтернатива пространственной случайности
# наблюдаемое I является экстремальным (высоким или низким)
# полученных на основе перестановок.
# Out:
# 0.001

# %% [markdown]
# ### 3) Локальная автокорреляция (ЛИЗА)

# %%
# Отобразим диаграмму рассеяния Морана - отражающую зависимость
# зависимой переменной от ее пространсвенного лага, в нашем случае
# это линейная положительная зависимость, визуализирующая взаимодействие. 

y = m17['price_m2']
b, a = np.polyfit(y, ylag, 1)
f, ax = plt.subplots(1, figsize=(9, 9))

plt.plot(y, ylag, '.', color = 'firebrick')

# dashed vert at mean of the price
plt.vlines(y.mean(), ylag.min(), ylag.max(), linestyle='--')

# dashed horizontal at mean of lagged price

plt.hlines (ylag.mean(), y.min(), y.max(), linestyle = '--')

# red line of best fit using global moran
plt.plot(y, a + b*y, 'r')
plt.title('Moran Scatterplot')
plt.ylabel('Spatial Lag of Price')
plt.xlabel('Price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Расчитываем Локальный Индекс Морана

li = esda.moran.Moran_Local(y, kw)
# Out:
# <frozen importlib._bootstrap>:914: ImportWarning: _SixMetaPathImporter.find_spec() not found; falling back to find_module()

# %%
li.q # расположение квадрантов 1 НН, 2 LH, 3 LL, 4 HL
# Out:
# array([1, 1, 1, ..., 1, 3, 4])

# %%
# обозначаем случаи вне пространсвенной случайности
sig = 1 * (li.p_sim < 0.05)
sig.sum()
# Out:
# 2644

# %%
# определям квадранты булевым произведением

hotspot = 1 * (sig * li.q==1)
coldspot = 3 * (sig * li.q==3)
doughnut = 2 * (sig* li.q==2)
diamond = 4 * (sig * li.q==4)

# %%
# складываем все в один массив

spots = hotspot + coldspot + doughnut + diamond
spots
# Out:
# array([0, 0, 0, ..., 0, 3, 0])

# %%
# для каждого значения в массиве назначаем квадрант, полученный массив
# визуализируем категориальными значениями

spot_labels = ['0 ns', '1 hot spot', '2 doughnut', '3 cold spot', '4 diamond']
labels = [spot_labels[i] for i in spots]
labels
# Out:
# ['0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '4 diamond',
#  '3 cold spot',
#  '3 cold spot',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '4 diamond',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '4 diamond',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '1 hot spot',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '0 ns',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '3 cold spot',
#  '3 cold spot',
#  '0 ns',
#  '3 cold spot',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '3 cold spot',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '3 cold spot',
#  '3 cold spot',
#  '4 diamond',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '3 cold spot',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '2 doughnut',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '0 ns',
#  '4 diamond',
#  '3 cold spot',
#  '0 ns',
#  '3 cold spot',
#  '3 cold spot',
#  '4 diamond',
#  '3 cold spot',
#  '4 diamond',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '4 diamond',
#  '3 cold spot',
#  '4 diamond',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '4 diamond',
#  '4 diamond',
#  '4 diamond',
#  '0 ns',
#  '3 cold spot',
#  '3 cold spot',
#  '4 diamond',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '4 diamond',
#  '3 cold spot',
#  '4 diamond',
#  '3 cold spot',
#  '3 cold spot',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '4 diamond',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '3 cold spot',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '4 diamond',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '4 diamond',
#  '3 cold spot',
#  '4 diamond',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '4 diamond',
#  '4 diamond',
#  '0 ns',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '0 ns',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '4 diamond',
#  '4 diamond',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '0 ns',
#  '3 cold spot',
#  '4 diamond',
#  '3 cold spot',
#  '3 cold spot',
#  '4 diamond',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '0 ns',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '4 diamond',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '4 diamond',
#  '3 cold spot',
#  '3 cold spot',
#  '4 diamond',
#  '3 cold spot',
#  '3 cold spot',
#  '4 diamond',
#  '4 diamond',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '4 diamond',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '3 cold spot',
#  '4 diamond',
#  '4 diamond',
#  '4 diamond',
#  '4 diamond',
#  '3 cold spot',
#  '4 diamond',
#  '3 cold spot',
#  '0 ns',
#  '3 cold spot',
#  '3 cold spot',
#  '4 diamond',
#  '4 diamond',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '4 diamond',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '4 diamond',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '3 cold spot',
#  '4 diamond',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '3 cold spot',
#  '4 diamond',
#  '3 cold spot',
#  '3 cold spot',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '4 diamond',
#  '0 ns',
#  '4 diamond',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '2 doughnut',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '2 doughnut',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '3 cold spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '2 doughnut',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '2 doughnut',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '0 ns',
#  '0 ns',
#  '4 diamond',
#  '2 doughnut',
#  '1 hot spot',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '2 doughnut',
#  '2 doughnut',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '1 hot spot',
#  '2 doughnut',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '2 doughnut',
#  '1 hot spot',
#  '2 doughnut',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '2 doughnut',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '0 ns',
#  '2 doughnut',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '2 doughnut',
#  '1 hot spot',
#  '0 ns',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  '1 hot spot',
#  ...]

# %%
from matplotlib import colors 
hmap = colors.ListedColormap(['darkgrey', 'red', 'lightblue', 'blue','pink'])

f,ax = plt.subplots (1, figsize = (8.26,5.826))

minsk.plot(ax=ax, color = 'lavender',alpha = .3, edgecolor = 'red')
highways.plot(ax=ax, color = 'grey', alpha = 0.2)
buildings.plot(ax=ax, color='grey', alpha = 0.5)

m17.assign(cl=labels).plot(column='cl', categorical=True,
                           k=2, cmap=hmap,
                           markersize=8,
                           linewidth=0.1, ax=ax,
                           edgecolor='white', legend=True
                          )


ax.set_title('LISA',
             fontsize = 14)
#ax.legend(loc='lower left')
# scalebar = AnchoredSizeBar(ax.transData, 1, "1 Meter", 9)
ax.add_artist(ScaleBar(dx = 1,
                       location = 'lower left'
                      ),) # 1 pixel = 1 м
# m17.legend(frameon=False, loc=0, ncol=2)
ax.set_axis_off()
plt.show
plt.savefig('LISA.png', format='png', dpi=300)

# %% [markdown]
# ## GWR

# %%
from mgwr.gwr import GWR, MGWR # моделирование ГВР и МГВР
from mgwr.sel_bw import Sel_BW # выбор полосы пропускания

# %%
# подготовка исходных данных
# выбор зависимой переменной, факторов

y = m17['price_m2'].values.reshape((-1,1))
x = m17[['rooms', 'area_total', 'year',#'b','k','kb','m','p','sb',
        'parks_dist','metro_dist', 'hospitals_dist','schools_dist',
        'transport_dist','highways_dist','industrial_dist']].values

# получение списка координат
u = m17['x']
v = m17['y']
coords = list(zip(u,v))

# нормализация данных
x = (x-x.mean(axis=0))/x.std(axis=0)
y = y.reshape((-1,1))
y = (y-y.mean(axis=0)/y.std(axis=0))

# %%
# калибровка ГВР-модели
# %time
gwr_selector = Sel_BW(coords, # координаты
                      y,x, # зависимая и независимые переменные
                      kernel = 'gaussian', # тип ядра
                      fixed = False).search(criterion = 'AICc')
# Out:
# CPU times: user 1e+03 ns, sys: 3 µs, total: 4 µs
# Wall time: 6.44 µs

# %%
print(gwr_selector)
# Out:
# 63.0

# %%
gwr = GWR(coords,
          y, x,
          gwr_bw,
          kernel ='gaussian',
         fixed = False)
res = gwr.fit()
# Out:
# aicc: 78822.77019802321
# ENP: 30.245297375062705
# sigma2: 47801.5666146369

# %%
print('aicc:', res.aicc)
print ('ENP:', res.ENP)
print('sigma2:', res.sigma2)
print('R2:', res.R2)
print('D2', res.R2)
print('Adjucted R2:', res.adj_R2)
print('std_res: ',res.std_res)
# Out:
# aicc: 78822.77019802321
# ENP: 30.245297375062705
# sigma2: 47801.5666146369
# R2: 0.24736247236379982
# D2 0.24736247236379982
# Adjucted R2: 0.2434082052437141
# std_res:  [[ 0.32750977]
#  [ 0.51112452]
#  [ 1.91401769]
#  ...
#  [ 3.12341821]
#  [-0.83461415]
#  [ 0.83115268]]

# %%
res.summary()
# Out:
# ===========================================================================
# Model type                                                         Gaussian
# Number of observations:                                                5788
# Number of covariates:                                                    11
#
# Global Regression Results
# ---------------------------------------------------------------------------
# Residual sum of squares:                                       297820589.769
# Log-likelihood:                                                  -39608.259
# AIC:                                                              79238.517
# AICc:                                                             79240.571
# BIC:                                                           297770540.486
# R2:                                                                   0.186
# Adj. R2:                                                              0.184
#
# Variable                              Est.         SE  t(Est/SE)    p-value
# ------------------------------- ---------- ---------- ---------- ----------
# X0                                1235.682      2.984    414.043      0.000
# X1                                 -98.191      4.430    -22.163      0.000
# X2                                  81.117      4.468     18.156      0.000
# X3                                   1.522      3.000      0.507      0.612
# X4                                 -16.245      3.022     -5.375      0.000
# X5                                 -37.743      3.379    -11.170      0.000
# X6                                 -28.830      3.167     -9.103      0.000
# X7                                   8.557      3.106      2.755      0.006
# X8                                 -12.119      3.001     -4.039      0.000
# X9                                 -35.167      3.384    -10.391      0.000
# X10                                -10.114      3.246     -3.116      0.002
#
# Geographically Weighted Regression (GWR) Results
# ---------------------------------------------------------------------------
# Spatial kernel:                                           Adaptive gaussian
# Bandwidth used:                                                    1396.000
#
# Diagnostic information
# ---------------------------------------------------------------------------
# Residual sum of squares:                                       275229694.968
# Effective number of parameters (trace(S)):                           30.245
# Degree of freedom (n - trace(S)):                                  5757.755
# Sigma estimate:                                                     218.636
# Log-likelihood:                                                  -39379.965
# AIC:                                                              78822.420
# AICc:                                                             78822.770
# BIC:                                                              79030.624
# R2:                                                                   0.247
# Adjusted R2:                                                          0.243
# Adj. alpha (95%):                                                     0.018
# Adj. critical t value (95%):                                          2.363
#
# Summary Statistics For GWR Parameter Estimates
# ---------------------------------------------------------------------------
# Variable                   Mean        STD        Min     Median        Max
# -------------------- ---------- ---------- ---------- ---------- ----------
# X0                     1235.627      9.977   1220.131   1233.626   1255.569
# X1                      -94.361      5.856   -105.776    -95.140    -83.143
# X2                       77.831     14.889     37.895     82.096     94.580
# X3                        2.169      2.578     -1.587      1.363      7.686
# X4                      -21.018      7.145    -34.731    -21.263     -8.655
# X5                      -33.977     22.939    -64.953    -45.521     14.956
# X6                      -30.695      6.052    -42.882    -28.654    -21.195
# X7                        9.510      7.355     -7.008      9.709     23.245
# X8                      -10.175      4.073    -16.464    -10.201     -2.060
# X9                      -49.184     12.232    -80.428    -47.026    -31.191
# X10                     -12.332      8.080    -24.842    -13.753      1.315
# ===========================================================================
